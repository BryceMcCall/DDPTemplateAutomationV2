# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook
import ast
import os

# %%
# Filtering function for report_df
def correct_list_string(s):
    # Check if the string starts with [ and ends with ] to ensure it looks like a list
    s = s.replace('?', '')

    if s.startswith('[') and s.endswith(']'):
        # Extract the contents inside the brackets and split them by comma
        items = s[1:-1].split(',')
        
        # Process each item to ensure it has single quotes around it
        corrected_items = []
        for item in items:
            # Strip spaces and any extra single quotes
            item_stripped = item.strip().strip("'")
            corrected_items.append(f"'{item_stripped}'")
        
        # Reconstruct the list string
        return '[' + ', '.join(corrected_items) + ']'
    return s

def filter_data(row):
    conditions = []
    debug_info = [] # To collect debug information

    # Create the unique ID from the filter_df's first three columns
    unique_id = f"{row['WorkbookID']}_{row['SheetID']}_{row['RowID']}"

    for col, value in row.items():
        # Skip the first three columns, columns that are not in report_df, columns with '*' as value, 
        # and the 'Year' column
        if col in ['WorkbookID', 'SheetID', 'RowID'] or col not in report_df.columns or value == "*":
            continue

         # If value is a string, remove spaces at the end
        if isinstance(value, str):
            value = value.rstrip()

        # Check and correct the string representation of list if necessary
        if isinstance(value, str) and value.startswith("["):
            if col != 'Year':  # Only correct if the column is not 'Year'
                value = correct_list_string(value)  # Correct the string representation
            value = ast.literal_eval(value)  # Convert the string to an actual list

        # If value is a list, check if the column value in report_df is in the list
        if isinstance(value, list):
            conditions.append(report_df[col].isin(value))
            debug_info.append(f"{col} is in {value}") # For debugging
        else:
            conditions.append(report_df[col] == value)
            debug_info.append(f"{col} == {value}") # For debugging
            

    
    # If there are no conditions to check, return the entire report_df
    if not conditions:
        return report_df
    
    # Combine all conditions with an AND operator
    combined_condition = conditions[0]
    for cond in conditions[1:]:
        combined_condition &= cond

    result = report_df[combined_condition].copy()  # Ensure not to modify the original dataframe
    result['UniqueID'] = unique_id  # Add the unique ID to the filtered result
    if result.empty:
        print(f"Filter {debug_info} resulted in empty dataframe.") # This will show the failed conditions
        

    return result

# Convert SATIMGE values based on Unit column
def convert_value(row):
    factor = conversion_factors.get(row['TargetUnit'])
    if factor:
        result_value = row['SATIMGE'] * factor
        return np.round(result_value, 6)
    # If unit not found in conversion_factors, return original value
    return row['SATIMGE']

# %%
path_Report = "input/REPORT_00_IMAGINE_runs.csv" # add/replace file path here or filename if in same directory
path_SetsAndMaps = "input/SetsAndMaps.xlsm" # add/replace file path here or filename if in same directory
path_Output = "input/merged_data.csv" # add/replace file path here or filename if in same directory

# Read in the DataFrames
report_df = pd.read_csv(path_Report, low_memory=False)
mapPRC_df = pd.read_excel(path_SetsAndMaps, sheet_name="mapPRC")
mapCOM_df = pd.read_excel(path_SetsAndMaps, sheet_name="mapCOM")

# Replace 'Eps' values with 0
report_df['SATIMGE'] = report_df['SATIMGE'].replace('Eps', 0)
report_df['SATIMGE'] = report_df['SATIMGE'].astype(float)

# Merge the DataFrames
merged_df = report_df.merge(mapPRC_df, on='Process', how='left')
merged_df = merged_df.merge(mapCOM_df, on='Commodity', how='left')

# Reset index
merged_df.reset_index(drop=True, inplace=True)

# merged_df.to_csv(path_Output, index=False)

# %%
#ADJUST THE EMISSIONS TO CO2EQ:

# set the emissions factors
emf_df = pd.DataFrame({'Indicator': ['CH4','N2O','C2F6','CF4'],
                    'E_factor': [28, 265,11100,6630]})

# Merge the two DataFrames based on the 'Indicator' column
merged_df = merged_df.merge(emf_df, on='Indicator', how='left')

# Fill missing values in 'Multiplier' column with 1
merged_df['E_factor'].fillna(1, inplace=True)

# Multiply the values from 'SATIMGE' by the 'E_factor' column
merged_df['Result'] = merged_df['SATIMGE'] * merged_df['E_factor']

# Optionally, drop the 'Multiplier' column or rename columns
merged_df = merged_df.drop('SATIMGE', axis=1) #dropping the original SATIMGE values.
merged_df = merged_df.drop('E_factor', axis=1)
#rename to new SATIMGE
merged_df = merged_df.rename(columns={'Result': 'SATIMGE'}) #new SATIMGE values

# Reset index
merged_df.reset_index(drop=True, inplace=True)

merged_df.head(30)
# Out:
#            Process Commodity  Year                   Scenario  Indicator  \
# 0   SATIMMarginals   CO2CAPT  2019  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 1   SATIMMarginals   CO2CAPT  2019  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 2   SATIMMarginals   CO2CAPT  2020  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 3   SATIMMarginals   CO2CAPT  2020  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 4   SATIMMarginals   CO2CAPT  2021  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 5   SATIMMarginals   CO2CAPT  2021  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 6   SATIMMarginals   CO2CAPT  2022  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 7   SATIMMarginals   CO2CAPT  2022  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 8   SATIMMarginals   CO2CAPT  2023  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 9   SATIMMarginals   CO2CAPT  2023  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 10  SATIMMarginals   CO2CAPT  2024  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 11  SATIMMarginals   CO2CAPT  2024  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 12  SATIMMarginals   CO2CAPT  2025  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 13  SATIMMarginals   CO2CAPT  2025  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 14  SATIMMarginals   CO2CAPT  2026  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 15  SATIMMarginals   CO2CAPT  2026  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 16  SATIMMarginals   CO2CAPT  2027  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 17  SATIMMarginals   CO2CAPT  2027  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 18  SATIMMarginals   CO2CAPT  2028  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 19  SATIMMarginals   CO2CAPT  2028  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 20  SATIMMarginals   CO2CAPT  2029  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 21  SATIMMarginals   CO2CAPT  2029  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 22  SATIMMarginals   CO2CAPT  2030  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 23  SATIMMarginals   CO2CAPT  2031  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 24  SATIMMarginals   CO2CAPT  2032  NZ10_2050A_09EESSNXCT-IMG  Marginals
# 25  SATIMMarginals   CO2CAPT  2032  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 26  SATIMMarginals   CO2CAPT  2032  NZ10_2099B_99NESSNXCT-IMG  Marginals
# 27  SATIMMarginals   CO2CAPT  2033  NZ10_2050A_09EESSNXCT-IMG  Marginals
# 28  SATIMMarginals   CO2CAPT  2033  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 29  SATIMMarginals   CO2CAPT  2033  NZ10_2099B_99NESSNXCT-IMG  Marginals
#
#    Sector Subsector Subsubsector        TechDescription IPCC_Category_L1  \
# 0     All       All          All  SATIMMarginals Annual              NaN
# 1     All       All          All  SATIMMarginals Annual              NaN
# 2     All       All          All  SATIMMarginals Annual              NaN
# 3     All       All          All  SATIMMarginals Annual              NaN
# 4     All       All          All  SATIMMarginals Annual              NaN
# 5     All       All          All  SATIMMarginals Annual              NaN
# 6     All       All          All  SATIMMarginals Annual              NaN
# 7     All       All          All  SATIMMarginals Annual              NaN
# 8     All       All          All  SATIMMarginals Annual              NaN
# 9     All       All          All  SATIMMarginals Annual              NaN
# 10    All       All          All  SATIMMarginals Annual              NaN
# 11    All       All          All  SATIMMarginals Annual              NaN
# 12    All       All          All  SATIMMarginals Annual              NaN
# 13    All       All          All  SATIMMarginals Annual              NaN
# 14    All       All          All  SATIMMarginals Annual              NaN
# 15    All       All          All  SATIMMarginals Annual              NaN
# 16    All       All          All  SATIMMarginals Annual              NaN
# 17    All       All          All  SATIMMarginals Annual              NaN
# 18    All       All          All  SATIMMarginals Annual              NaN
# 19    All       All          All  SATIMMarginals Annual              NaN
# 20    All       All          All  SATIMMarginals Annual              NaN
# 21    All       All          All  SATIMMarginals Annual              NaN
# 22    All       All          All  SATIMMarginals Annual              NaN
# 23    All       All          All  SATIMMarginals Annual              NaN
# 24    All       All          All  SATIMMarginals Annual              NaN
# 25    All       All          All  SATIMMarginals Annual              NaN
# 26    All       All          All  SATIMMarginals Annual              NaN
# 27    All       All          All  SATIMMarginals Annual              NaN
# 28    All       All          All  SATIMMarginals Annual              NaN
# 29    All       All          All  SATIMMarginals Annual              NaN
#
#    IPCC_Category_L2 IPCC_Category_L3 IPCC_Category_L4  \
# 0               NaN              NaN              NaN
# 1               NaN              NaN              NaN
# 2               NaN              NaN              NaN
# 3               NaN              NaN              NaN
# 4               NaN              NaN              NaN
# 5               NaN              NaN              NaN
# 6               NaN              NaN              NaN
# 7               NaN              NaN              NaN
# 8               NaN              NaN              NaN
# 9               NaN              NaN              NaN
# 10              NaN              NaN              NaN
# 11              NaN              NaN              NaN
# 12              NaN              NaN              NaN
# 13              NaN              NaN              NaN
# 14              NaN              NaN              NaN
# 15              NaN              NaN              NaN
# 16              NaN              NaN              NaN
# 17              NaN              NaN              NaN
# 18              NaN              NaN              NaN
# 19              NaN              NaN              NaN
# 20              NaN              NaN              NaN
# 21              NaN              NaN              NaN
# 22              NaN              NaN              NaN
# 23              NaN              NaN              NaN
# 24              NaN              NaN              NaN
# 25              NaN              NaN              NaN
# 26              NaN              NaN              NaN
# 27              NaN              NaN              NaN
# 28              NaN              NaN              NaN
# 29              NaN              NaN              NaN
#
#                                           Description  \
# 0   CO2 Captured                                  ...
# 1   CO2 Captured                                  ...
# 2   CO2 Captured                                  ...
# 3   CO2 Captured                                  ...
# 4   CO2 Captured                                  ...
# 5   CO2 Captured                                  ...
# 6   CO2 Captured                                  ...
# 7   CO2 Captured                                  ...
# 8   CO2 Captured                                  ...
# 9   CO2 Captured                                  ...
# 10  CO2 Captured                                  ...
# 11  CO2 Captured                                  ...
# 12  CO2 Captured                                  ...
# 13  CO2 Captured                                  ...
# 14  CO2 Captured                                  ...
# 15  CO2 Captured                                  ...
# 16  CO2 Captured                                  ...
# 17  CO2 Captured                                  ...
# 18  CO2 Captured                                  ...
# 19  CO2 Captured                                  ...
# 20  CO2 Captured                                  ...
# 21  CO2 Captured                                  ...
# 22  CO2 Captured                                  ...
# 23  CO2 Captured                                  ...
# 24  CO2 Captured                                  ...
# 25  CO2 Captured                                  ...
# 26  CO2 Captured                                  ...
# 27  CO2 Captured                                  ...
# 28  CO2 Captured                                  ...
# 29  CO2 Captured                                  ...
#
#                                     Short Description Commodity_Name   SATIMGE
# 0   CO2 Captured                                  ...              0 -0.438883
# 1   CO2 Captured                                  ...              0 -0.438883
# 2   CO2 Captured                                  ...              0  0.177243
# 3   CO2 Captured                                  ...              0 -0.438883
# 4   CO2 Captured                                  ...              0 -0.438883
# 5   CO2 Captured                                  ...              0 -0.438883
# 6   CO2 Captured                                  ...              0  0.144287
# 7   CO2 Captured                                  ...              0 -0.438883
# 8   CO2 Captured                                  ...              0 -0.118207
# 9   CO2 Captured                                  ...              0 -0.438883
# 10  CO2 Captured                                  ...              0 -0.438883
# 11  CO2 Captured                                  ...              0 -0.438883
# 12  CO2 Captured                                  ...              0 -0.241770
# 13  CO2 Captured                                  ...              0 -0.438883
# 14  CO2 Captured                                  ...              0 -0.313759
# 15  CO2 Captured                                  ...              0 -0.438883
# 16  CO2 Captured                                  ...              0 -0.390758
# 17  CO2 Captured                                  ...              0 -0.438883
# 18  CO2 Captured                                  ...              0 -0.438883
# 19  CO2 Captured                                  ...              0 -0.438883
# 20  CO2 Captured                                  ...              0 -0.438883
# 21  CO2 Captured                                  ...              0 -0.438883
# 22  CO2 Captured                                  ...              0 -0.438883
# 23  CO2 Captured                                  ...              0 -0.438883
# 24  CO2 Captured                                  ...              0 -0.045400
# 25  CO2 Captured                                  ...              0 -0.438883
# 26  CO2 Captured                                  ...              0 -0.438883
# 27  CO2 Captured                                  ...              0 -0.145955
# 28  CO2 Captured                                  ...              0 -0.438883
# 29  CO2 Captured                                  ...              0 -0.438883

# %%
scenarios = merged_df['Scenario'].unique() #array 
scenarios
# Out:
# array(['NZ10_2050A_08EESSNXCT_IMG', 'NZ10_2099B_99NESSNXCT-IMG',
#        'NZ10_2050A_09EESSNXCT-IMG'], dtype=object)

# %%
#path where all filters are
filter_folder = 'input\\FilterScripts\\'
curr_wdr = os.getcwd()
filters_path = os.path.join(curr_wdr,filter_folder)

# Initialize an empty list to store DataFrames
dataframes = []

# Iterate over files in the directory
for filename in os.listdir(filters_path):
    if filename.endswith('.xlsx'):
        print(filename)
        file_path = os.path.join(filters_path, filename)
        df = pd.read_excel(file_path)
        df = df.dropna()
        dataframes.append(df)

# Concatenate all DataFrames into one
combined_df = pd.concat(dataframes, ignore_index=True)

# Drop rows with NaN values
combined_df = combined_df.dropna()

# Fill NaN values with 0 for the specified columns
columns_to_convert = ['WorkbookID', 'SheetID', 'RowID']

if not combined_df.empty:
    combined_df[columns_to_convert] = combined_df[columns_to_convert].fillna(0).astype(int)

# Split the 'TargetUnit' column if needed
Units = combined_df[['WorkbookID', 'SheetID', 'RowID', 'TargetUnit']]
combined_df = combined_df.drop(columns=['TargetUnit'])

# Reset the index
combined_df.reset_index(drop=True, inplace=True)


# Now, 'combined_df' contains data from all the Excel files in the folder
filter_df = combined_df
# Out:
# commerce_filters.xlsx
# pass_transport_filter.xlsx
# res_filters.xlsx

# %% [markdown]
# ### rename the scenarios according to Workbook ID

# %%
# Create a mapping of WorkbookID values to corresponding scenario names
workbook_scenario_mapping = {
    1: 'NZ10_2099B_99NESSNXCT-IMG',
    2: 'NZ10_2050A_08EESSNXCT_IMG',
    3: 'NZ10_2050A_09EESSNXCT-IMG'
}

# Define a function to update the 'Scenario' column based on conditions
def update_scenario(row):
    scenario = row['Scenario']
    workbook_id = row['WorkbookID']
    
    # Check if the scenario name is in the mapping and matches the WorkbookID
    if scenario in workbook_scenario_mapping and workbook_scenario_mapping[workbook_id] == scenario:
        return scenario  # No change is needed
        
    # Check if the scenario name is in the mapping but doesn't match the WorkbookID
    if scenario in workbook_scenario_mapping and workbook_scenario_mapping[workbook_id] != scenario:
        return workbook_scenario_mapping[workbook_id]  # Update to the correct scenario
    
    # If the scenario is not in the mapping, return the scenario based on WorkbookID
    if workbook_id in workbook_scenario_mapping:
        return workbook_scenario_mapping[workbook_id]
    
    # If neither scenario nor WorkbookID are in the mapping, return the existing scenario
    return scenario

# Update the 'Scenario' column in filter_df based on the defined conditions
filter_df['Scenario'] = filter_df.apply(update_scenario, axis=1)



#testing an edit

# %%
filter_df
# Out:
#      WorkbookID  SheetID  RowID Process   Commodity                      Year  \
# 0             1       18     38       *           *  [2020, 2030, 2040, 2050]
# 1             1       18     40       *           *  [2020, 2030, 2040, 2050]
# 2             1       18     41       *           *  [2020, 2030, 2040, 2050]
# 3             1       18     42       *           *  [2020, 2030, 2040, 2050]
# 4             1       18     43       *           *  [2020, 2030, 2040, 2050]
# ..          ...      ...    ...     ...         ...                       ...
# 384           3       16    130       *  ['RESBIW']  [2020, 2030, 2040, 2050]
# 385           3       16    133       *           *  [2020, 2030, 2040, 2050]
# 386           1       16     19       *           *  [2020, 2030, 2040, 2050]
# 387           2       16     19       *           *  [2020, 2030, 2040, 2050]
# 388           3       16     19       *           *  [2020, 2030, 2040, 2050]
#
#                       Scenario       Indicator SATIMGE           Sector  \
# 0    NZ10_2099B_99NESSNXCT-IMG    ['Activity']       *     ['Commerce']
# 1    NZ10_2099B_99NESSNXCT-IMG    ['Activity']       *     ['Commerce']
# 2    NZ10_2099B_99NESSNXCT-IMG    ['Activity']       *     ['Commerce']
# 3    NZ10_2099B_99NESSNXCT-IMG    ['Activity']       *     ['Commerce']
# 4    NZ10_2099B_99NESSNXCT-IMG    ['Activity']       *     ['Commerce']
# ..                         ...             ...     ...              ...
# 384  NZ10_2050A_09EESSNXCT-IMG         ['CO2']       *  ['Residential']
# 385  NZ10_2050A_09EESSNXCT-IMG  ['N2O', 'CH4']       *  ['Residential']
# 386  NZ10_2099B_99NESSNXCT-IMG               *       *   ['Population']
# 387  NZ10_2050A_08EESSNXCT_IMG               *       *   ['Population']
# 388  NZ10_2050A_09EESSNXCT-IMG               *       *   ['Population']
#
#     Subsector       Subsubsector TechDescription IPCC_Category_L1  \
# 0           *                  *               *                *
# 1           *  ['Space Heating']               *                *
# 2           *        ['Cooling']               *                *
# 3           *        ['Cooking']               *                *
# 4           *  ['Water Heating']               *                *
# ..        ...                ...             ...              ...
# 384         *                  *               *                *
# 385         *                  *               *                *
# 386         *                  *               *                *
# 387         *                  *               *                *
# 388         *                  *               *                *
#
#     IPCC_Category_L2 IPCC_Category_L3 IPCC_Category_L4 Description  \
# 0                  *                *                *           *
# 1                  *                *                *           *
# 2                  *                *                *           *
# 3                  *                *                *           *
# 4                  *                *                *           *
# ..               ...              ...              ...         ...
# 384                *                *                *           *
# 385                *                *                *           *
# 386                *                *                *           *
# 387                *                *                *           *
# 388                *                *                *           *
#
#     Short Description Commodity_Name
# 0                   *              *
# 1                   *              *
# 2                   *              *
# 3                   *              *
# 4                   *              *
# ..                ...            ...
# 384                 *              *
# 385                 *              *
# 386                 *              *
# 387                 *              *
# 388                 *              *
#
# [389 rows x 20 columns]

# %%
Units['UniqueID'] = Units['WorkbookID'].astype(str) + '_' + Units['SheetID'].astype(str) + '_' + Units['RowID'].astype(str)
Units.drop(columns=['WorkbookID', 'SheetID', 'RowID'], inplace=True)

# %%
Units['UniqueID']
# Out:
# 0       1_18_38
# 1       1_18_40
# 2       1_18_41
# 3       1_18_42
# 4       1_18_43
#          ...
# 384    3_16_130
# 385    3_16_133
# 386     1_16_19
# 387     2_16_19
# 388     3_16_19
# Name: UniqueID, Length: 389, dtype: object

# %%
columns = ['Process', 'Commodity', 'Year', 'Scenario', 'Indicator',
       'Sector', 'Subsector', 'Subsubsector', 'TechDescription',
       'IPCC_Category_L1', 'IPCC_Category_L2', 'IPCC_Category_L3',
       'IPCC_Category_L4', 'Description', 'Short Description',
       'Commodity_Name']

for col in columns:
    print(col, " unique values: \n", merged_df[col].unique(), "\n \n", '--------------------------------########################--------------------', '\n \n')

#ORG_NZ10_8
# Out:
# Process  unique values:
#  ['SATIMMarginals' 'I2A1' 'I2A3' 'I2B2' 'I2B5' 'I2B6' 'I2B8' 'I2C1' 'I2C2'
#  'I2C3' 'I2C5' 'I2C6' 'I2D1' 'I2D2' 'I2F1' 'I2F2' 'I2F3' 'I2F4' 'A3A1a'
#  'A3A1c' 'A3A1d' 'A3A1f' 'A3A1g' 'A3A1h' 'A3A2a' 'A3A2c' 'A3A2d' 'A3A2f'
#  'A3A2g' 'A3A2h' 'A3A2i' 'L3B1a' 'L3B1b' 'L3B2a' 'L3B2b' 'L3B3a' 'L3B3b'
#  'L3B4' 'L3B5a' 'L3B5b' 'L3B6b' 'A3C1a' 'A3C1b' 'A3C1c' 'A3C1d' 'A3C1e'
#  'A3C2' 'A3C3' 'A3C4' 'A3C5' 'A3C6' 'L3D1' 'W4A' 'W4B' 'W4C2' 'W4D1'
#  'AHCOA-E' 'AHELC-E' 'AHOHF-E' 'AHOKE-E' 'AIELC-E' 'AIODS-E' 'AOELC-E'
#  'APELC-E' 'ATELC-E' 'ATODS-E' 'CECELCCEN-E' 'CECELCCEN-N' 'CECELCCHIL-E'
#  'CECELCHP-E' 'CECELCROOM-E' 'CEGELCHAL-E' 'CEGELCHPM-E' 'CEGELCHPS-E'
#  'CEGELCINC-E' 'CEGELCLED-N' 'CEGELCMHL-E' 'CEHCOA-E' 'CEHELC-E'
#  'CEHELC-N' 'CEHGAS-E' 'CEHGAS-N' 'CEKCOA-E' 'CEKELC-E' 'CEKOLP-E'
#  'CELELCCFL-E' 'CELELCFLU-E' 'CELELCHAL-E' 'CELELCHID-E' 'CELELCINC-E'
#  'CELELCLED-N' 'CEOELC-E' 'CEOODS-E' 'CEOOHF-E' 'CERELC-E' 'CERELC-N'
#  'CETELC-E' 'CEWCOA-E' 'CEWELC-E' 'CEWELCHP-N' 'CEWGAS-E' 'CEWOKE-E'
#  'CEWOLP-E' 'CNCELCCEN-E' 'CNCELCCEN-N' 'CNCELCCHIL-E' 'CNCELCHP-E'
#  'CNCELCROOM-E' 'CNHCOA-E' 'CNHELC-E' 'CNHELC-N' 'CNHGAS-E' 'CNHGAS-N'
#  'CNKCOA-E' 'CNKELC-E' 'CNKOLP-E' 'CNLELCCFL-E' 'CNLELCFLU-E'
#  'CNLELCHAL-E' 'CNLELCHID-E' 'CNLELCINC-E' 'CNLELCLED-N' 'CNOELC-E'
#  'CNOGAS-E' 'CNOODS-E' 'CNOOGS-E' 'CNOOHF-E' 'CNOOKE-E' 'CNRELC-E'
#  'CNRELC-N' 'CNWCOA-E' 'CNWELC-E' 'CNWELCHP-N' 'CNWGAS-E' 'CNWOKE-E'
#  'CNWOLP-E' 'EDILS' 'EDMLR' 'EPTSTO-E' 'EPTSTO-N' 'ERBIO-N' 'ERHYD-E'
#  'ERHYDGIW-I' 'ERHYD-I' 'ERHYD-N' 'ERSOLPCF-N' 'ERSOLPCT-N' 'ERSOLPRA-N'
#  'ERSOLPRM-N' 'ERSOLPRC-N' 'ERSOLPRI-N' 'ERSOLPRR-N' 'ERSOLTC09-N'
#  'ERWNDH-N' 'ESTSUTL' 'ETCLEARNO-E' 'ETCLECAMD-E' 'ETCLEDUVH-E'
#  'ETCLEGROO-E' 'ETCLEHEND-E' 'ETCLEKELB-E' 'ETCLEKEND-E' 'ETCLEKOMA-E'
#  'ETCLEKRIE-E' 'ETCLEKUSI-N' 'ETCLELETH-E' 'ETCLEMAJD-E' 'ETCLEMAJW-E'
#  'ETCLEMATI-E' 'ETCLEMATL-E' 'ETCLEMEDU-N' 'ETCLEPFSI-E' 'ETCLEPFSS-E'
#  'ETCLETUTU-E' 'ETCLEWATE-N' 'ETGASENSI-N' 'ETGASENSS-N' 'ETGICCC-N'
#  'ETGICCC-CCS-N' 'ETGICGT-N' 'ETNUC-E' 'ETNUC-N' 'ETODSGT-E' 'ETODSGT-N'
#  'ETRANS' 'ETRANSDUM' 'HETP-N' 'HFCP-TRAHCV-N' 'IALPOT' 'IALPOTINERT'
#  'ICPAELC-E' 'ICPCELC-E' 'ICPEELC-E' 'ICPFELC-E' 'ICPHELC-E' 'ICPKELC-E'
#  'ICPLELC-E' 'ICPOELC-E' 'ICPPELC-E' 'ICPSCLE-E' 'ICPSELC-E' 'ICPSELC-N'
#  'ICPSHGN-N' 'ICPSGAS-E' 'ICPSOHF-E' 'ICPSWAS-E' 'ICPTGMU-E' 'ICPGASMTH'
#  'ICPGASNH3-E' 'ICPHGNMTH' 'ICPNH3DEM' 'IFCEAFB-N' 'IFCEAF-E' 'IFCEAF-N'
#  'IFBAELC-E' 'IFBCELC-E' 'IFBFELC-E' 'IFBHELC-E' 'IFBKELC-E' 'IFBLELC-E'
#  'IFBOELC-E' 'IFBPELC-E' 'IFBSBIB-E' 'IFBSCOA-E' 'IFBSELC-E' 'IFBSELC-N'
#  'IFBSGAS-E' 'IFBSOHF-E' 'IFBSWAS-E' 'IFMEAFB-N' 'IFMEAF-E' 'IFMEAF-N'
#  'IISBFBOF-E' 'IISBFBOF-N' 'IISCOREAF-E' 'IISCOV' 'IISDRIEAF-E'
#  'IISHDRIEAF-N' 'IISHHDRI-N' 'IISHALKHGNO' 'IISXHGNCRS' 'IISOTHEAF-E'
#  'IISSCREAF-E' 'IISSCREAF-N' 'IMIAELC-E' 'IMICELC-E' 'IMIEELC-E'
#  'IMIFELC-E' 'IMIHELC-E' 'IMIKELC-E' 'IMILELC-E' 'IMIOELC-E' 'IMIPELC-E'
#  'IMIRODS-E' 'IMIRELC-E' 'IMISCOA-E' 'IMISELC-E' 'IMISELC-N' 'IMISHGN-N'
#  'IMISGAS-E' 'IMISOHF-E' 'IMISOLP-E' 'IMISWAS-E' 'IMPGRL' 'IMPNH3'
#  'IMPNUC' 'IMPOAG' 'IMPOCR' 'IMPODS' 'IMPOGS' 'IMPOHF' 'IMPOKE' 'IMPOLP'
#  'INFAELC-E' 'INFEELC-E' 'INFHELC-E' 'INFKELC-E' 'INFLELC-E' 'INFOELC-E'
#  'INFSCOA-E' 'INFSELC-E' 'INFSGAS-E' 'INFSOHF-E' 'INFSWAS-E' 'INMBRIADV'
#  'INMBRISTD' 'INMCEMF2TF' 'INMCEMFGBM' 'INMCEMFGRP' 'INMCEMKLD-E'
#  'INMCEMKPP-E' 'INMCEMKSP-E' 'INMCEMKSP-N' 'INMCEMPGBM' 'INMCEMPGRP'
#  'INMCLISUBASH' 'INMCLISUBCLY' 'INMCLISUBGYL' 'INMCLISUBSLAG'
#  'INMCLISUBSPOZ' 'INMGLAADV' 'INMGLASTD' 'INMLIMSTD' 'IOTAELC-E'
#  'IOTCELC-E' 'IOTEELC-E' 'IOTFELC-E' 'IOTHELC-E' 'IOTKELC-E' 'IOTLELC-E'
#  'IOTOELC-E' 'IOTPELC-E' 'IOTRODS-E' 'IOTRELC-E' 'IOTSCOA-E' 'IOTSELC-E'
#  'IOTSELC-N' 'IOTSHGN-E' 'IOTSGAS-E' 'IOTSOHF-E' 'IOTSWAS-E' 'IPGMME-E'
#  'IPGMME-N' 'IPPCHE-E' 'IPPCHE-N' 'IPPDIS-E' 'IPPELCSTM-E' 'IPPMCH-E'
#  'IPPPAP-E' 'IPPREC-E' 'IPPSTMBIO-E' 'IPPSTMBIO-N' 'IPPSTMBLQ-E'
#  'IPPSTMCOA-E' 'IPPSTMCOAOIL' 'IPPSTMGAS-E' 'MINBIB' 'MINBIO' 'MINBIW'
#  'MINCLE' 'MINCOA' 'MINCSARNOVRS' 'MINCSCAMDVRS' 'MINCSDUVHVRS'
#  'MINCSGROOVRS' 'MINCSHENDVRS' 'MINCSKENDS32' 'MINCSKOMAVRS'
#  'MINCSKRIEVRS' 'MINCSKUSINLG' 'MINCSKUSIVRS' 'MINCSLETHSER'
#  'MINCSMAJUVRS' 'MINCSMATIEXX' 'MINCSMATLVRS' 'MINCSMEDUEXX'
#  'MINCSTUTUVRS' 'MINFEORE' 'MINGIB' 'MINGIC' 'MINHYD' 'MINSOL' 'MINWAS'
#  'MINWND' 'MIRGRS' 'PEXCOA' 'PEXELC' 'PEXPGM' 'PEXPGMO' 'RHEHBIWSTOV-E'
#  'RHEHCOASTOV-E' 'RHEHELCHEATFIN-E' 'RHEHGASHEAT-N' 'RHEHOKEHEAT-E'
#  'RHEHOLPHEAT-E' 'RHEKBIWSTOV-E' 'RHEKELCSTOV-E' 'RHEKOKEPRIMUS-E'
#  'RHEKOLPSTOV-E' 'RHELELCINC-E' 'RHEOELCOTH-E' 'RHERELCREF-E'
#  'RHEWELCCHP-N' 'RHEWELCGEY-E' 'RHEWELCSWH-E' 'RLEHBIWOPEN-E'
#  'RLEHCOABNM-E' 'RLEHELCHEATBAR-E' 'RLEHOKEHEAT-E' 'RLEHOLPHET-E'
#  'RLEKBIWBNM-E' 'RLEKCOABNM-E' 'RLEKELCHOT-E' 'RLEKOKEWICK-E'
#  'RLEKOLPRING-E' 'RLELELCINC-E' 'RLELOKEOKE' 'RLEOELCOTH-E' 'RLERELCREF-E'
#  'RLEWBIWKETBI-E' 'RLEWCOAKETCOA-E' 'RLEWELCKET-E' 'RLEWOKEKETWI-E'
#  'RLEWOLPKETLPG-E' 'RMEHBIWSTOV-E' 'RMEHCOASTOV-E' 'RMEHELCHEATFIN-E'
#  'RMEHOKEHEAT-E' 'RMEHOLPHEAT-E' 'RMEKBIWSTOV-E' 'RMEKCOABNM-E'
#  'RMEKELCSTOV-E' 'RMEKGASSTOV-E' 'RMEKOKEWICK-E' 'RMEKOLPSTOV-E'
#  'RMELELCINC-E' 'RMELOKEOKE' 'RMEOELCOTH-E' 'RMERELCREF-E'
#  'RMEWBIWKETBI-E' 'RMEWCOASTOV-E' 'RMEWELCGEY-E' 'RMEWELCKET-E'
#  'RMEWELCSWH-E' 'RMEWGASGEY-N' 'RMEWOKEKETPR-E' 'RMEWOLPKETLPG-E'
#  'TADJETOKE-E' 'TADJETOKE-N' 'TAIJETOKE-E' 'TAIJETOKE-N' 'TAOAGOAG-E'
#  'TAOAGOAG-N' 'TFHCV1ELC-N' 'TFHCV1ODS-E' 'TFHCV1ODS-N' 'TFHCV1OGS-E'
#  'TFHCV2ELC-N' 'TFHCV2ODS-E' 'TFHCV2ODS-N' 'TFHCV3ELC-N' 'TFHCV3ODS-E'
#  'TFHCV3ODS-N' 'TFHCV4ELC-N' 'TFHCV4HGN-N' 'TFHCV4ODS-E' 'TFHCV4ODS-N'
#  'TFHCV5ELC-N' 'TFHCV5HGN-N' 'TFHCV5ODS-E' 'TFHCV5ODS-N' 'TFHCV6ELC-N'
#  'TFHCV6HGN-N' 'TFHCV6ODS-E' 'TFHCV6ODS-N' 'TFHCV7ELC-N' 'TFHCV7GAS-N'
#  'TFHCV7HGN-N' 'TFHCV7ODS-E' 'TFHCV7ODS-N' 'TFHCV8ELC-N' 'TFHCV8GAS-N'
#  'TFHCV8HGN-N' 'TFHCV8ODS-E' 'TFHCV8ODS-N' 'TFHCV9ELC-N' 'TFHCV9GAS-N'
#  'TFHCV9HGN-N' 'TFHCV9ODS-E' 'TFHCV9ODS-N' 'TFLCVELC-N' 'TFLCVODS-E'
#  'TFLCVODS-N' 'TFLCVOGS-E' 'TFLCVOGS-N' 'TFPIPELC-E' 'TFPIPELC-N'
#  'TFRCOELC-E' 'TFRCOELC-N' 'TFRCOODS-E' 'TFREXELC-N' 'TFREXELCR-E'
#  'TFREXODSR-E' 'TFROTELC-E' 'TFROTELC-N' 'TFROTODS-E' 'TPPRCARELC-N'
#  'TPPRCARHGNF-N' 'TPPRCARODS-E' 'TPPRCARODS-N' 'TPPRCAROGS-E'
#  'TPPRCAROGSH-E' 'TPPRCAROGS-N' 'TPPRMOTELC-N' 'TPPRMOTOGS-E'
#  'TPPRMOTOGS-N' 'TPPRSUVELC-N' 'TPPRSUVHGNF-N' 'TPPRSUVODS-E'
#  'TPPRSUVODS-N' 'TPPRSUVOGS-E' 'TPPRSUVOGSH-E' 'TPPRSUVOGSH-N'
#  'TPPRSUVOGS-N' 'TPPUBRTBGS-N' 'TPPUBRTELC-N' 'TPPUBRTGAS-N'
#  'TPPUBRTODS-N' 'TPPUBUSGAS-N' 'TPPUBUSODS-E' 'TPPUBUSODS-N'
#  'TPPUGATELC-N' 'TPPUMBTODS-E' 'TPPUMBTOGS-E' 'TPPUMBTOGS-N'
#  'TPPUMERELC-E' 'TPPUMERELC-N' 'TSHFOOHF-E' 'TSHFOOHF-N' 'UCO2SPCEM'
#  'UCO2SPIFC' 'UCO2SPIFM' 'UCO2STOR' 'UPWRCO2SCD' 'UCTLCLEIN-E' 'UCTLNH3-E'
#  'UELEA1HGN' 'UELEP1HGN' 'UDACCO2S2' 'UGASGIB-N' 'UGASGIC-N' 'UGASGRS-N'
#  'UGTLGICCO-E' 'UHETCLE-E' 'ULGTGRL-N' 'UREFOCRCA-E' 'UREFOCRCO-E'
#  'UREFOCRIN-E' 'UTRNGIMGAS' 'XAGRCOA' 'XAGRELC' 'XAGRODS' 'XAGROHF'
#  'XAGROKE' 'XCO2TRANSPORT' 'XCOMCOA' 'XCOMELC' 'XCOMGAS' 'XCOMODS'
#  'XCOMOGS' 'XCOMOHF' 'XCOMOKE' 'XCOMOLP' 'XICPELC' 'XIFAELC' 'XIFBELC'
#  'XIISELC' 'XIMIELC' 'XINDBIB' 'XINDBIO' 'XINDBIW' 'XINDCLE' 'XINDCMU'
#  'XINDCOA' 'XINDELC' 'XINDGAS' 'XINDGMU' 'XINDHGN' 'XINDOMU' 'XINDODS'
#  'XINDOHF' 'XINDOLP' 'XINDWAS' 'XINDWMU' 'XINFELC' 'XINMELC' 'XIOTELC'
#  'XIPGM' 'XIPPBIO' 'XIPPELC' 'XIPPOTH' 'XIPPREC' 'XPWRBIO' 'XPWRCLE'
#  'XPWRGAS' 'XPWRGIC' 'XPWRHYD' 'XPWRNUC' 'XPWRODS' 'XPWROHF' 'XPWROKE'
#  'XPWRSOL' 'XPWRWND' 'XRESBIW' 'XRESCOA' 'XRESELC' 'XRESGAS' 'XRESOKE'
#  'XRESOLP' 'XTRAELC' 'XTRAGAS' 'XTRAHGN' 'XTRAOAG' 'XTRAODS' 'XTRAOGS'
#  'XTRAOHF' 'XTRAOKE' 'XUPSCLE' 'XUPSELC' 'XUPSGAS' 'XUPSGIC' 'XUPSOCR']
#
#  --------------------------------########################--------------------
#
#
# Commodity  unique values:
#  ['CO2CAPT' 'CF4' 'AGRCOA' 'AGRODS' 'AGROHF' 'AGROKE' 'AGROLP' 'BIB' 'BIO'
#  'BIW' 'CEH' 'CEK' 'CEO' 'CEW' 'CF6' 'CH4C' 'CH4S' 'CH4SF' 'CLD' 'CLE'
#  'CNH' 'CNK' 'CNO' 'CNW' 'CO2C' 'CO2EQS' 'CO2S' 'CO2SF' 'CO2SP' 'CO2SPCEM'
#  'CO2SCCEM' 'CO2SPIFC' 'CO2SPIFM' 'CO2STOR' 'COA' 'COMCOA' 'COMGAS'
#  'COMODS' 'COMOGS' 'COMOHF' 'COMOKE' 'COMOLP' 'GAS' 'GIB' 'GIC' 'GIH'
#  'GIM' 'GRL' 'GRS' 'HEE' 'HEN' 'HGN' 'IALM' 'ICPNH3' 'ICPS' 'ICPT' 'IFACR'
#  'IFACHA' 'IFAMN' 'IFBS' 'IISCKE' 'IISCRS' 'IISFEORE' 'IISHBI' 'IISHGCRS'
#  'IISHHGN' 'IMIR' 'IMIS' 'INDBIB' 'INDBIW' 'INDCLE' 'INDCMU' 'INDCOA'
#  'INDGAS' 'INDGMU' 'INDHGN' 'INDODS' 'INDOHF' 'INDOLP' 'INDOMU' 'INDWAS'
#  'INDWMU' 'INFS' 'INMBRI' 'INMCEM' 'INMCEMTHF' 'INMCLI' 'INMCLISUB'
#  'INMGLA' 'INMLIM' 'INMRWM' 'IOTR' 'IOTS' 'IPGMD' 'IPGM' 'IPGMOP' 'IPPBIO'
#  'IPPBLQ' 'IPPOHF' 'IPPPAP' 'IPPPULP' 'IPPPULPD' 'IPPSTM' 'MTH' 'N2OS'
#  'NH3' 'NH3G' 'NUC' 'OAG' 'OCR' 'ODS' 'OGS' 'OHF' 'OKE' 'OKG' 'OLP'
#  'PWRBIG' 'PWRBIO' 'PWRCLD' 'PWRCLE' 'PWRCLEARNO' 'PWRCLECAMD'
#  'PWRCLEDUVH' 'PWRCLEGROO' 'PWRCLEHEND' 'PWRCLEKEND' 'PWRCLEKOMA'
#  'PWRCLEKRIE' 'PWRCLEKUSI' 'PWRCLELETH' 'PWRCLEMAJU' 'PWRCLEMATI'
#  'PWRCLEMATL' 'PWRCLEMEDU' 'PWRCLETUTU' 'PWRGAS' 'PWRGIC' 'PWRHGN'
#  'PWRHYD' 'PWRNUC' 'PWRODS' 'PWROHF' 'PWROKE' 'PWRSOL' 'PWRWND' 'PWRWAT'
#  'RESBIW' 'RESCOA' 'RESGAS' 'RESOKE' 'RESOLP' 'TADJET' 'TAIJET' 'TAOAG'
#  'TFHCV1' 'TFHCV2' 'TFHCV3' 'TFHCV4' 'TFHCV5' 'TFHCV6' 'TFHCV7' 'TFHCV8'
#  'TFHCV9' 'TFLCV' 'TFPIP' 'TFRCO' 'TFREX' 'TFROT' 'TPPRCAR' 'TPPRMOT'
#  'TPPRSUV' 'TPPUBRT' 'TPPUBUS' 'TPPUGAT' 'TPPUMBT' 'TPPUMER' 'TRAGAS'
#  'TRAHGN' 'TRAOAG' 'TRAODS' 'TRAOGS' 'TRAOHF' 'TRAOKE' 'TSHFO' 'UPSCLE'
#  'UPSGAS' 'UPSGIC' 'UPSHEE' 'UPSHEN' 'UPSOCR' 'WAS' 'ACTGRP' 'AH' 'CMOX'
#  'NMVS' 'NOXS' 'PM10S' 'SOXS' 'AGRELC' 'AI' 'AO' 'AP' 'AT' 'CEC' 'COMELC'
#  'CEG' 'CEL' 'CER' 'CET' 'CNC' 'CNL' 'CNR' 'ELCC' 'IMIELC' 'INDELC'
#  'RESELC' 'PWRENV' 'ICPELC' 'UPSELC' 'ELC' 'INFELC' 'ICPA' 'ICPC' 'ICPE'
#  'ICPF' 'ICPH' 'ICPK' 'ICPL' 'ICPO' 'ICPP' 'IFAELC' 'IFBA' 'IFBELC' 'IFBC'
#  'IFBF' 'IFBH' 'IFBK' 'IFBL' 'IFBO' 'IFBP' 'IISBFSLG' 'IISELC' 'IMIA'
#  'IMIC' 'IMIE' 'IMIF' 'IMIH' 'IMIK' 'IMIL' 'IMIO' 'IMIP' 'INFE' 'INFH'
#  'INFK' 'INFL' 'INFO' 'INMELC' 'IOTA' 'IOTELC' 'IOTC' 'IOTE' 'IOTF' 'IOTH'
#  'IOTK' 'IOTL' 'IOTO' 'IOTP' 'IPPELC' 'IPPREC' 'HYD' 'SOL' 'WND'
#  'ZDUMETRANS' 'RHEH' 'RHEK' 'RHEL' 'RHEO' 'RHER' 'RHEWG' 'RLEH' 'RLEK'
#  'RLEL' 'RLNL' 'RLEO' 'RLER' 'RLEW' 'RMEH' 'RMEK' 'RMEL' 'RMNL' 'RMEO'
#  'RMER' 'RMEW' 'RMEWG' 'TRAELC' 'OTH']
#
#  --------------------------------########################--------------------
#
#
# Year  unique values:
#  [2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2032
#  2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045 2046
#  2047 2048 2049 2050 2051 2052 2053 2054 2055 2058 2063 2068]
#
#  --------------------------------########################--------------------
#
#
# Scenario  unique values:
#  ['NZ10_2050A_08EESSNXCT_IMG' 'NZ10_2099B_99NESSNXCT-IMG'
#  'NZ10_2050A_09EESSNXCT-IMG']
#
#  --------------------------------########################--------------------
#
#
# Indicator  unique values:
#  ['Marginals' 'CO2' 'CO2CAPT' 'N2O' 'CH4' 'CF4' 'C2F6' 'CO2eq' 'Activity'
#  'FuelCosts' 'FlowIn' 'FlowInMt' 'FlowOut' 'GVA' 'Capacity' 'CapFac'
#  'AnnInvCost' 'FOM' 'Investment' 'NewCapacity' 'VOM' 'Price' 'tkm' 'pkm']
#
#  --------------------------------########################--------------------
#
#
# Sector  unique values:
#  ['All' 'Process Emissions' 'Agri Emissions' 'Land Emissions' 'Waste'
#  'Agriculture' 'Commerce' 'Power' 'Industry' nan 'Hydrogen' 'Supply'
#  'Residential' 'Transport' 'CO2Capture&Storage' 'Refineries' 'Ammonia']
#
#  --------------------------------########################--------------------
#
#
# Subsector  unique values:
#  ['All' 'Process Emissions' 'Agri Emissions' 'Land Emissions' 'Waste'
#  'Agriculture' 'ComExisting' 'ComNew' 'Demand' 'EPumpStorage' 'EBiomass'
#  'EHydro' 'Imports' 'EPV' 'ECSP' 'EWind' 'EBattery' 'ECoal'
#  'AutoGen-Chemical' 'AutoGen-EnergySupply' 'EGas' 'EGas_CCS' 'ENuclear'
#  'EOil' 'ETrans' 'Electrolysers' 'FuelCells' 'Aluminium35220'
#  'Chemicals33' nan 'Ammonia' 'FerroAlloys' 'Food_Bev_Tob30'
#  'Iron_Steel351' 'Onsite H2 Production-Iron and Steel' 'Mining2'
#  'PNFMetals352' 'NMMProducts34' 'NMMGlass' 'IndOther' 'PGM'
#  'Pulp_Paper323' 'Extraction-Bio' 'Extraction-Coal' 'Extraction-Ores'
#  'Extraction-Gas' 'Extraction-RE' 'Exports' 'HighIncome' 'LowIncome'
#  'MiddleIncome' 'Aviation-Domestic' 'Aviation-International' 'FreightRoad'
#  'FreightPip' 'FreightRail' 'PassPriv' 'PassPub' 'TraOther'
#  'CO2Capture&Storage-Industry' 'CO2Capture&Storage-Storage'
#  'CO2Capture&Storage-Power' 'CTL' 'Hydrogen-Elc' 'DAC' 'GTL' 'CTL-Boiler'
#  'CrudeRef' 'EDist' '1B2 Oil and Natural Gas'
#  '1A1c Manufacture of solid fuels and other energy industries']
#
#  --------------------------------########################--------------------
#
#
# Subsubsector  unique values:
#  ['All' 'Process Emissions' 'Agri Emissions' 'Land Emissions' 'Waste'
#  'Other' 'Cooling' 'Public Lights' 'Space Heating' 'Cooking' 'Lighting'
#  'Refrigeration' 'Public Water' 'Water Heating' 'Demand' 'EPumpStorage'
#  'EBiomass' 'EHydro' 'EImports' 'EPV_Grid' 'EPV_Dist' 'ECSP' 'EWind'
#  'Ebattery_Grid' 'ECoal_Existing' 'AutoGen-Chemical-Coal'
#  'AutoGen-EnergySupply-Coal' 'Ecoal_New' 'AutoGen-Chemical-Gas'
#  'AutoGen-EnergySupply-Gas' 'EGas' 'Egas_CCS' 'Koeberg' 'New Nuclear'
#  'EOil' 'Etrans' 'ETrans' 'Electrolysers' 'FuelCells' 'Smelters'
#  'Compressed Air' 'Electrochemical' 'Fans' 'HVAC' 'Electric Heating'
#  'Other Motive' 'Pumping' 'Process Heat ' 'Material Use' nan 'Ammonia'
#  'FerroChrome' 'FerroManganese' 'BFBOF-Existing' 'BFBOF-New'
#  'COREAF-Existing' 'Coke Ovens' 'DRIEAF-Existing' 'DRIEAFGas-New'
#  'Hydrogen DRI' 'Onsite H2 Production-Iron and Steel-Alkaline'
#  'Green Steel' 'OtherEAF-Existing' 'SCREAF-Existing' 'SCREAF-New'
#  'Imports' 'Bricks' 'Cement' 'Glass' 'Lime' 'PGM' 'Chemical Pulping'
#  'Disolving Pulping' 'Mechanical Pulping' 'Paper Mill' 'Boiler Plant'
#  'Coal_CB' 'Coal_WB' 'Mining of Iron Ore' 'Gas_Cl' 'Exports' 'Aviation'
#  'HCV1Electric' 'HCV1Oil' 'HCV2-5Electric' 'HCV2-5Oil' 'HCV2-5Hydrogen'
#  'HCV6-9Electric' 'HCV6-9Hydrogen' 'HCV6-9Oil' 'HCV6-9Gas' 'LCVElectric'
#  'LCVOil' 'FreightPip' 'FreightRail' 'CarElectric' 'CarHydrogen' 'CarOil'
#  'MotoElectric' 'MotoOil' 'SUVElectric' 'SUVHydrogen' 'SUVOil' 'SUVHybrid'
#  'BRTFlex' 'BRTElc' 'BRTGas' 'BRTOil' 'BusGas' 'BusOil' 'PassengerRail'
#  'MinibusOil' 'TraOther' 'CO2Capture&Storage-Industry'
#  'CO2Capture&Storage-Storage' 'CO2Capture&Storage-Power' 'CTL'
#  'Hydrogen-Elc-Alkaline' 'Hydrogen-Elc-PEM' 'DAC' 'Pipeline' 'GTL' 'LNG'
#  'CrudeRef' 'EDist Agriculture' 'EDist Commercial' 'EDist Industry'
#  'EDist Residential' 'Edist Transport']
#
#  --------------------------------########################--------------------
#
#
# TechDescription  unique values:
#  ['SATIMMarginals Annual' 'Process Emissions 2A1' 'Process Emissions 2A3'
#  'Process Emissions 2B2' 'Process Emissions 2B5' 'Process Emissions 2B6'
#  'Process Emissions 2B8' 'Process Emissions 2C1' 'Process Emissions 2C2'
#  'Process Emissions 2C3' 'Process Emissions 2C5' 'Process Emissions 2C6'
#  'Process Emissions 2D1' 'Process Emissions 2D2' 'Process Emissions 2F1'
#  'Process Emissions 2F2' 'Process Emissions 2F3' 'Process Emissions 2F4'
#  'Agri Emissions 3A1a' 'Agri Emissions 3A1c' 'Agri Emissions 3A1d'
#  'Agri Emissions 3A1f' 'Agri Emissions 3A1g' 'Agri Emissions 3A1h'
#  'Agri Emissions 3A2a' 'Agri Emissions 3A2c' 'Agri Emissions 3A2d'
#  'Agri Emissions 3A2f' 'Agri Emissions 3A2g' 'Agri Emissions 3A2h'
#  'Agri Emissions 3A2i' 'Land Emissions 3B1a' 'Land Emissions 3B1b'
#  'Land Emissions 3B2a' 'Land Emissions 3B2b' 'Land Emissions 3B3a'
#  'Land Emissions 3B3b' 'Land Emissions 3B4' 'Land Emissions 3B5a'
#  'Land Emissions 3B5b' 'Land Emissions 3B6b' 'Agri Emissions 3C1a'
#  'Agri Emissions 3C1b' 'Agri Emissions 3C1c' 'Agri Emissions 3C1d'
#  'Agri Emissions 3C1e' 'Agri Emissions 3C2' 'Agri Emissions 3C3'
#  'Agri Emissions 3C4' 'Agri Emissions 3C5' 'Agri Emissions 3C6'
#  'Land Emissions 3D1' 'Waste Emissions 4A' 'Waste Emissions 4B'
#  'Waste Emissions 4C2' 'Waste Emissions 4D1'
#  'Agriculture - Heating-Coal - Existing             '
#  'Agriculture - Heating - Electricity - Room - Exist'
#  'Agriculture - Heating - Oil HFO- Existing         '
#  'Agriculture - Heating - Oil Paraffin- Existing    '
#  'Agriculture - Irrigation - Electricity - Existing '
#  'Agriculture - Irrigation - Oil Diesel - Existing  '
#  'Agriculture - Other - Electricity - Existing      '
#  'Agriculture - Processing - Electricity - Existing '
#  'Agriculture - Traction - Electricity - Existing   '
#  'Agriculture - Traction - Oil Diesel - Existing    '
#  'Commercial - Cooling - Electricity - Central - Exi'
#  'Commercial - Cooling - Electricity - Central - New'
#  'Commercial - Cooling - Electricity - Chiller - Exi'
#  'Commercial - Cooling - Electricity - Heat Pump - E'
#  'Commercial - Cooling - Electricity - Room - Existi'
#  'Commercial - Public Lights - Electricity - HAL - E'
#  'Commercial - Public Lights - Electricity - HPM - E'
#  'Commercial - Public Lights - Electricity - HPS - E'
#  'Commercial - Public Lights - Electricity - INC - E'
#  'Commercial - Public Lights - Electricity - LED - N'
#  'Commercial - Public Lights - Electricity - MHL - E'
#  'Commercial - Space Heating - Coal - Existing      '
#  'Commercial - Space Heating - Electricity - Existin'
#  'Commercial - Space Heating - Electricity - New    '
#  'Commercial - Space Heating - Gas - Existing       '
#  'Commercial - Space Heating - Gas - New            '
#  'Commercial - Cooking - Coal - Existing            '
#  'Commercial - Cooking - Electricity - Existing     '
#  'Commercial - Cooking - Oil LPG - Existing         '
#  'Commercial - Lighting - Electricity - CFL - Existi'
#  'Commercial - Lighting - Electricity - FLU - Existi'
#  'Commercial - Lighting - Electricity - HAL - Existi'
#  'Commercial - Lighting - Electricity - HID - Existi'
#  'Commercial - Lighting - Electricity - INC - Existi'
#  'Commercial - Lighting - Electricity - LED - New   '
#  'Commercial - Other - Electricity - Existing       '
#  'Commercial - Other - Oil Diesel - Existing        '
#  'Commercial - Other - Oil HFO - Existing           '
#  'Commercial - Refrigeration - Electricity - Existin'
#  'Commercial - Refrigeration - Electricity - New    '
#  'Commercial - Public Water - Electricity -  - Exist'
#  'Commercial - Water Heating - Coal - Existing      '
#  'Commercial - Water Heating - Electricity - Existin'
#  'Commercial - Water Heating - Electricity - HP - Ne'
#  'Commercial - Water Heating - Gas - Existing       '
#  'Commercial - Water Heating - Oil Paraffin - Existi'
#  'Commercial - Water Heating - Oil LPG - Existing   '
#  'Commercial - Other - Gas - Existing               '
#  'Commercial - Other - Oil Gasoline - Existing      '
#  'Commercial - Other - Oil Paraffin - Existing      '
#  'Interruptible Supply' 'Manual Load Reduction (load shedding)'
#  'Pumped Storage Existing' 'Pumped Storage New'
#  'Biomass municipal waste                           '
#  'Hydro Existing South Africa                       '
#  'Grand Inga (West)                                 '
#  'Hydro Existing Region                             '
#  'Micro hydro                                       '
#  'Solar PV Fixed                                    '
#  'Solar PV tracking                                 '
#  'Solar PV rooftop Agriculture' 'Solar PV rooftop Mining'
#  'Solar PV rooftop commercial                       '
#  'Solar PV rooftop Industry                         '
#  'Solar PV rooftop residential                      '
#  'Solar Central Receiver 09 hrs storage             '
#  'Wind high resource                                '
#  'Utility storage - Li ion battery                  '
#  'ARNOT                                             '
#  'CAMDEN                                            '
#  'DUVHA                                             '
#  'GROOTVLEI                                         '
#  'HENDRINA                                          '
#  'KELVIN B                                          '
#  'KENDAL                                            '
#  'KOMATI                                            '
#  'KRIEL                                             ' 'KUSILE'
#  'LETHABO                                           '
#  'MAJUBA DRY                                        '
#  'MAJUBA WET                                        '
#  'MATIMBA                                           '
#  'MATLA                                             ' 'MEDUPI'
#  'Sasol Infrachem                                   '
#  'Sasol SSF                                         '
#  'TUTUKA                                            '
#  'Generic Waterberg Coal Plant' 'Sasol Infrachem Gas Plant '
#  'Sasol SSF Gas Plant ' 'Combined Cycle Gas Turbine - LNG'
#  'Combined Cycle Gas Turbine - LNG with CCS         '
#  'Open Cycle Gas Turbine - LNG'
#  'Nuclear Existing                                  '
#  'Nuclear Mid                                       '
#  'OCGT liquid fuels Existing                        ' 'DOE Peakers'
#  'Transmission                                      '
#  'dummy tech tracking investment costs'
#  'Electrolyser H2 PEM generic export                '
#  'Fuel Cell H2 PEM Transport HCV'
#  'Aluminium smelters - potlines                     '
#  'Aluminium smelters - potlines - inert anodes      '
#  'Industry-Chemicals-Compressed air - Electricity   '
#  'Industry-Chemicals-Cooling - Electricity          '
#  'Industry-Chemicals-Electrochemical - Electricity  '
#  'Industry-Chemicals-Fans - Electricity             '
#  'Industry-Chemicals-HVAC - Electricity             '
#  'Industry-Chemicals-Elec Heating - Electricity     '
#  'Industry-Chemicals-Lighting - Electricity         '
#  'Industry-Chemicals-Other motive - Electricity     '
#  'Industry-Chemicals-Pumping - Electricity          '
#  'Industry-Chemicals-boiler/process heating - Coal -'
#  'Industry-Chemicals-boiler/process heating - Electr'
#  'Industry-Chemicals-boiler/process heating - Electricity - Heat Pump New'
#  'Industry-Chemicals-boiler/process heating - Hydrogen - New'
#  'Industry-Chemicals-boiler/process heating - Gas - '
#  'Industry-Chemicals-boiler/process heating - Oil HF'
#  'Industry-Chemicals-boiler/process heating - Waste '
#  'Industry-Chemicals-Ancillary - Gas Material Use - Existing     ' nan
#  'Existing Ammonia Plant - Gas                      '
#  'Ammonia to Local Market                           '
#  'FerroChrome with biomass                          '
#  'FerroChrome existing                              '
#  'FerrChrome New                                    '
#  'Industry-Food, Beverage & Tabacco-Compressed air -'
#  'Industry-Food, Beverage & Tabacco-Cooling - Electr'
#  'Industry-Food, Beverage & Tabacco-Fans - Electrici'
#  'Industry-Food, Beverage & Tabacco-HVAC - Electrici'
#  'Industry-Food, Beverage & Tabacco-Elec Heating - E'
#  'Industry-Food, Beverage & Tabacco-Lighting - Elect'
#  'Industry-Food, Beverage & Tabacco-Other motive - E'
#  'Industry-Food, Beverage & Tabacco-Pumping - Electr'
#  'Industry-Food, Beverage & Tabacco-boiler/process h'
#  'Industry-Food, Beverage & Tabacco-boiler/process heating - Electricity - Heat Pump New'
#  'FerroMn with biomass                              '
#  'FerroMn existing                                  '
#  'FerroMn New                                       '
#  'Industry - Iron&Steel - BF BOF route - Existing   '
#  'Industry - Iron&Steel - BF BOF route - New build  '
#  'Industry - Iron&Steel - Corex EAF - Existing      '
#  'Industry - Iron&Steel - Coke oven                 '
#  'Industry - Iron&Steel - Coal DRI-EAF route - Exist'
#  'Industry - Iron&Steel - Hydrogen DRI route - EAF  '
#  'Industry - Iron&Steel - Hydrogen DRI route - Hydro'
#  'Industry Iron and Steel - Alkaline Electrolyser - '
#  'Industry - I&S - green steel to local steel       '
#  'Industry - Iron&Steel - Other EAF - Existing      '
#  'Industry - Iron&Steel - Scrap Electric Arc Furnace'
#  'Industry-Mining-Compressed air - Electricity      '
#  'Industry-Mining-Cooling - Electricity             '
#  'Industry-Mining-Electrochemical - Electricity     '
#  'Industry-Mining-Fans - Electricity                '
#  'Industry-Mining-HVAC - Electricity                '
#  'Industry-Mining-Elec Heating - Electricity        '
#  'Industry-Mining-Lighting - Electricity            '
#  'Industry-Mining-Other motive - Electricity        '
#  'Industry-Mining-Pumping - Electricity             '
#  'Industry-Mining-Transport - Oil Diesel - Existing '
#  'Industry-Mining-Transport - Electricity - New     '
#  'Industry-Mining-boiler/process heating - Coal - Ex'
#  'Industry-Mining-boiler/process heating - Electricity - Heat Pump New'
#  'Industry-Mining-boiler/process heating - Hydrogen - New'
#  'Industry-Mining-boiler/process heating - Gas - Exi'
#  'Industry-Mining-boiler/process heating - Oil HFO -'
#  'Industry-Mining-boiler/process heating - Oil LPG -'
#  'Industry-Mining-boiler/process heating - Waste - E'
#  'Imports of Gas Regional LNG                       ' 'Imports of Ammonia'
#  'Imports of Nuclear                                '
#  'Imports of Oil Av Gasoline                        '
#  'Imports of Oil Crude                              '
#  'Imports of Oil Diesel                             '
#  'Imports of Oil Gasoline                           '
#  'Imports of Oil HFO                                '
#  'Imports of Oil Kerosene                           '
#  'Imports of Oil LPG                                '
#  'Industry-Precious & Non-Ferrous metals-Compressed '
#  'Industry-Precious & Non-Ferrous metals-Electrochem'
#  'Industry-Precious & Non-Ferrous metals-HVAC - Elec'
#  'Industry-Precious & Non-Ferrous metals-Elec Heatin'
#  'Industry-Precious & Non-Ferrous metals-Lighting - '
#  'Industry-Precious & Non-Ferrous metals-Other motiv'
#  'Industry-Precious & Non-Ferrous metals-boiler/proc'
#  'Industry - Non-metallic minerals - Bricks and cera'
#  'Industry - Non-metallic minerals - Cement - Fuel t'
#  'Industry - Non-metallic minerals - Cement - Finish'
#  'Industry - Non-metallic minerals - Cement - Kiln L'
#  'Industry - Non-metallic minerals - Cement - Kiln N'
#  'Industry - Non-metallic minerals - Cement - Kiln S'
#  'Industry - Non-metallic minerals - Cement - Pre-gr'
#  'Industry - NMM - Cement sector subtitution - coal '
#  'Industry - NMM - Cement sector subtitution - Clay '
#  'Industry - NMM - Cement sector subtitution - Gypsu'
#  'Industry - NMM - Cement sector subtitution - Blast'
#  'Industry - NMM - Cement sector subtitution - Lime '
#  'Industry - Non-metallic minerals - Glass - Advance'
#  'Industry - Non-metallic minerals - Glass - Standar'
#  'Industry - Non-metallic minerals - Lime - Standard'
#  'Industry-Other-Compressed air - Electricity       '
#  'Industry-Other-Cooling - Electricity              '
#  'Industry-Other-Electrochemical - Electricity      '
#  'Industry-Other-Fans - Electricity                 '
#  'Industry-Other-HVAC - Electricity                 '
#  'Industry-Other-Elec Heating - Electricity         '
#  'Industry-Other-Lighting - Electricity             '
#  'Industry-Other-Other motive - Electricity         '
#  'Industry-Other-Pumping - Electricity              '
#  'Industry-Other-Transport - Oil Diesel - Existing  '
#  'Industry-Other-Transport - Electricity - New      '
#  'Industry-Other-boiler/process heating - Coal - Exi'
#  'Industry-Other-boiler/process heating - Electricit'
#  'Industry-Other-boiler/process heating - Electricity - Heat Pump New'
#  'Industry-Other-boiler/process heating - Hydrogen - New'
#  'Industry-Other-boiler/process heating - Gas - Exis'
#  'Industry-Other-boiler/process heating - Oil HFO - '
#  'Industry-Other-boiler/process heating - Waste - Ex'
#  'Industry - PGMs - Mine and refine - existing'
#  'Industry - PGMs - Mine and refine - New'
#  'Industry - Pulp&Paper - Chemical Pulping - Existin'
#  'Industry - Pulp&Paper - Chemical Pulping - New bui'
#  'Industry - Pulp&Paper - Dissolving pulping - Exist'
#  'Industry - Pulp&Paper - Steam turbine - Existing  '
#  'Industry - Pulp&Paper - Mechanical Pulping - Exist'
#  'Industry - Pulp&Paper - Paper mill - Existing     '
#  'Industry - Pulp&Paper - Recovered paper pulping - '
#  'Industry - Pulp&Paper - Boiler plant - Biomass fir'
#  'Industry - Pulp&Paper - Recovery boiler - Black li'
#  'Industry - Pulp&Paper - Boiler plant - Coal fired '
#  'Industry - Pulp&Paper - Boiler plant - Coal Oil fi'
#  'Industry - Pulp&Paper - Boiler plant - Gas fired  '
#  'Renewable Resource: Biomass bagasse               '
#  'Renewable Resource: Biomass Other                 '
#  'Renewable Resource: Biomass Wood                  '
#  'Extraction of Coal low grade                      '
#  'Extraction of Coal                                '
#  'Coal Supply for Arnot-various' 'Coal Supply for Camden-various'
#  'Coal Supply for Duvha-various' 'Coal Supply for Grootvlei-various'
#  'Coal Supply for Hendrina-various' 'Coal Supply for Kendal-South 32'
#  'Coal Supply for Komati-various' 'Coal Supply for Kriel-various'
#  'Coal Supply for Kusile-New Largo' 'Coal Supply for Kusile-various'
#  'Coal Supply for Lethabo-Seriti' 'Coal Supply for Majuba-various'
#  'Coal Supply for Matimba-Exxaro ' 'Coal Supply for Matla-various'
#  'Coal Supply for Medupi-Exxaro' 'Coal Supply for Tutuka-various'
#  'Extraction of Iron ore                            '
#  'Extraction of Gas Indigenous Ibhubezi             '
#  'Extraction of Coastal Gas                         '
#  'Renewable Resource: Hydro                         '
#  'Renewable Resource: Solar                         '
#  'Renewable Resource: Waste                         '
#  'Renewable Resource: Wind                          '
#  'Extraction of Gas Southern Mozambique             '
#  'Exports of Coal                                   '
#  'Exports of Electricity                            ' 'Export PGMs - Pt'
#  'Export PGMs - Others'
#  'Residential - Space Heating - High Income Electrif'
#  'Residential - Cooking - High Income Electrified - '
#  'Residential - Lighting - High Income Electrified -'
#  'Residential - Other - High Income Electrified - El'
#  'Residential - Refrigeration - High Income Electrif'
#  'Residential - Water Heating - High Income Electrif'
#  'Residential - Space Heating - Low Income Electrifi'
#  'Residential - Cooking - Low Income Electrified - B'
#  'Residential - Cooking - Low Income Electrified - C'
#  'Residential - Cooking - Low Income Electrified - E'
#  'Residential - Cooking - Low Income Electrified - O'
#  'Residential - Lighting - Low Income Electrified - '
#  'Residential - Lighting - Low Income  -Paraffin - PAR - E'
#  'Residential - Other - Low Income Electrified - Ele'
#  'Residential - Refrigeration - Low Income Electrifi'
#  'Residential - Water Heating - Low Income Electrifi'
#  'Residential - Space Heating - Middle Income Electr'
#  'Residential - Cooking - Middle Income Electrified '
#  'Residential - Lighting - Middle Income Electrified'
#  'Residential - Lighting - Middle Income  - Oil Paraffin - WICK - E'
#  'Residential - Other - Middle Income Electrified - '
#  'Residential - Refrigeration - Middle Income Electr'
#  'Residential - Water Heating - Middle Income Electr'
#  'Transport Other -  Aviation Dom Jet Fuel -E       '
#  'Transport Other -  Aviation Dom Jet Fuel  Oil Jet '
#  'Transport Other -  Aviation Int Jet Fuel -E       '
#  'Transport Other -  Aviation Int Jet Fuel  Oil Jet '
#  'Transport Other - Aviation Gasoline-E             '
#  'Transport Other - Aviation Gasoline T-N           '
#  'Transport Freight - HCV1 Electricity-N            '
#  'Transport Freight - HCV1 Oil Diesel-E             '
#  'Transport Freight - HCV1 Oil Diesel-N             '
#  'Transport Freight - HCV1 Oil Gasoline-E           '
#  'Transport Freight - HCV2 Electricity-N            '
#  'Transport Freight - HCV2 Oil Diesel-E             '
#  'Transport Freight - HCV2 Oil Diesel-N             '
#  'Transport Freight - HCV3 Electricity-N            '
#  'Transport Freight - HCV3 Oil Diesel-E             '
#  'Transport Freight - HCV3 Oil Diesel-N             '
#  'Transport Freight - HCV4 Electricity-N'
#  'Transport Freight - HCV4 Hydrogen-N               '
#  'Transport Freight - HCV4 Oil Diesel-E             '
#  'Transport Freight - HCV4 Oil Diesel-N             '
#  'Transport Freight - HCV5 Electricity-N'
#  'Transport Freight - HCV5 Hydrogen-N               '
#  'Transport Freight - HCV5 Oil Diesel-E             '
#  'Transport Freight - HCV5 Oil Diesel-N             '
#  'Transport Freight - HCV6 Electricity-N'
#  'Transport Freight - HCV6 Hydrogen-N               '
#  'Transport Freight - HCV6 Oil Diesel-E             '
#  'Transport Freight - HCV6 Oil Diesel-N             '
#  'Transport Freight - HCV7 Electricity-N'
#  'Transport Freight - HCV7 Gas-N                    '
#  'Transport Freight - HCV7 Hydrogen-N               '
#  'Transport Freight - HCV7 Oil Diesel-E             '
#  'Transport Freight - HCV7 Oil Diesel-N             '
#  'Transport Freight - HCV8 Electricity-N'
#  'Transport Freight - HCV8 Gas-N                    '
#  'Transport Freight - HCV8 Hydrogen-N               '
#  'Transport Freight - HCV8 Oil Diesel-E             '
#  'Transport Freight - HCV8 Oil Diesel-N             '
#  'Transport Freight - HCV9 Electricity-N'
#  'Transport Freight - HCV9 Gas-N                    '
#  'Transport Freight - HCV9 Hydrogen-N               '
#  'Transport Freight - HCV9 Oil Diesel-E             '
#  'Transport Freight - HCV9 Oil Diesel-N             '
#  'Transport Freight - LCV Electricity-N             '
#  'Transport Freight - LCV Oil Diesel-E              '
#  'Transport Freight - LCV Oil Diesel-N              '
#  'Transport Freight - LCV Oil Gasoline-E            '
#  'Transport Freight - LCV Oil Gasoline-N            '
#  'Transport Other - Pipeline Electricity-E          '
#  'Transport Other - Pipeline Electricity-N          '
#  'Transport Freight - Rail Corridor Electricity-E   '
#  'Transport Freight - Rail Corridor Electricity-N   '
#  'Transport Freight - Rail Corridor Oil Diesel-E    '
#  'Transport Freight - Rail Export (bulk mining) Elec'
#  'Transport Freight - Rail Export (bulk mining) Oil '
#  'Transport Freight - Rail Other Electricity-E      '
#  'Transport Freight - Rail Other Electricity-N      '
#  'Transport Freight - Rail Other Oil Diesel-E       '
#  'Transport Passenger Car Priv.Veh. Electricity-N   '
#  'Transport Passenger Car Priv.Veh. Hydrogen Fuel Ce'
#  'Transport Passenger Car Priv.Veh. Oil Diesel-E    '
#  'Transport Passenger Car Priv.Veh. Oil Diesel-N    '
#  'Transport Passenger Car Priv.Veh. Oil Gasoline-E  '
#  'Transport Passenger Car Priv.Veh. Oil GasolineHybr'
#  'Transport Passenger Car Priv.Veh. Oil Gasoline-N  '
#  'Transport Passenger Moto Priv.Veh. Electricity-N  '
#  'Transport Passenger Moto Priv.Veh. Oil Gasoline-E '
#  'Transport Passenger Moto Priv.Veh. Oil Gasoline-N '
#  'Transport Passenger SUV Priv.Veh. Electricity-N   '
#  'Transport Passenger SUV Priv.Veh. Hydrogen Fuel Ce'
#  'Transport Passenger SUV Priv.Veh. Oil Diesel-E    '
#  'Transport Passenger SUV Priv.Veh. Oil Diesel-N    '
#  'Transport Passenger SUV Priv.Veh. Oil Gasoline-E  '
#  'Transport Passenger SUV Priv.Veh. Oil GasolineHybr'
#  'Transport Passenger SUV Priv.Veh. Oil Gasoline Hyb'
#  'Transport Passenger SUV Priv.Veh. Oil Gasoline-N  '
#  'Transport Passenger BRT Oil Blended Gasoline-Ethan'
#  'Transport Passenger BRT Electricity-N             '
#  'Transport Passenger BRT Gas-N                     '
#  'Transport Passenger BRT Oil Diesel-N              '
#  'Transport Passenger Bus Gas-N                     '
#  'Transport Passenger Bus Oil Diesel-E              '
#  'Transport Passenger Bus Oil Diesel-N              '
#  'Transport Passenger Gautrain Electricity-N        '
#  'Transport Passenger Minibus Oil Diesel-E          '
#  'Transport Passenger Minibus Oil Gasoline-E        '
#  'Transport Passenger Minibus Oil Gasoline-N        '
#  'Transport Passenger Metro Rail Electricity-E      '
#  'Transport Passenger Metro Rail Electricity-N      '
#  'Transport Other - HFO-E                           '
#  'Transport Other - HFO Oil HFO-N                   '
#  'CO2SP Capture Cement                              '
#  'CO2SP Capture FerroChrome                         '
#  'CO2SP Capture FerroManganese                      '
#  'CO2 Storage - Durban Basin                        '
#  'PWRCO2S Power Sector Capture'
#  'Refinery CTL Existing                             '
#  'Ammonia Production linked to CTL production'
#  'Production Plant Hydrogen Electrolysis Alkaline   '
#  'Production Plant Hydrogen Electrolysis PEM        '
#  'Direct Air Capture for CO2S (cheaper option)      '
#  'Pipeline Gas Indigenous Ibhubezi                  '
#  'Pipeline Coastal Gas                              '
#  'Pipeline Gas Southern Mozambique                  '
#  'Refinery GTL Existing                             '
#  'Refinery CTL Boiler Existing                      '
#  'LNG Terminal                                      '
#  'Refinery Crude Oil Cape Town Existing'
#  'Refinery Crude Oil Durban Existing'
#  'Refinery Crude Oil Inland Existing                '
#  'Conversion Methane Rich Gas Natural Gas for use in'
#  'Agriculatural Coal                                '
#  'Agriculatural Electricity                         '
#  'Agriculatural Oil Diesel                          '
#  'Agriculatural Oil HFO                             '
#  'Agriculatural Oil Paraffin                        '
#  'CO2 Transport - Durban Basin                      '
#  'Commercial Coal                                   '
#  'Commercial Electricity                            '
#  'Commercial Gas South Africa                       '
#  'Commercial Oil Diesel                             '
#  'Commercial Oil Gasoline                           '
#  'Commercial Oil HFO                                '
#  'Commercial Oil Kerosene                           '
#  'Commercial Oil LPG                                '
#  'Industrial CP-Electricity                         '
#  'Industrial FA-Electricity                         '
#  'Industrial FB-Electricity                         '
#  'Industrial IS-Electricity                         '
#  'Industrial MI-Electricity                         '
#  'Industry Biomass bagasse                          '
#  'Industry Biochar                                  '
#  'Industry Biomass Wood                             '
#  'Industry Low Grade Coal                           '
#  'Industry Coal for Material Use'
#  'Industry Coal                                     '
#  'Industry Electricity                              '
#  'Industry Gas South Africa                         '
#  'Industry Gas Material Use'
#  'Industry Sector Hydrogen                          '
#  'Industry Oil HFO for material use'
#  'Industry Oil Diesel                               '
#  'Industry Oil HFO                                  '
#  'Industry Oil LPG                                  '
#  'Industry Waste                                    '
#  'Industry Waste for material use'
#  'Industrial NF-Electricity                         '
#  'Industrial NM-Electricity                         '
#  'Industrial OT-Electricity                         ' 'To local demand'
#  'Industry - Pulp and Paper - Biomass Bagasse (dummy'
#  'Industrial PP-Electricity                         '
#  'Industry - Pulp and paper - Oil LPG               '
#  'Generic supply - Industry - Recovered Paper       '
#  'Power Sector Biomass Other                        '
#  'Power Sector Coal low grade                       '
#  'Power Sector Gas South Africa                     '
#  'Power Sector Coastal Gas                          '
#  'Power Sector Hydro                                '
#  'Power Sector Nuclear                              '
#  'Power Sector Oil Diesel                           '
#  'Power Sector Oil HFO            '
#  'Power Sector Oil Kerosene                       '
#  'Power Sector Solar                                '
#  'Power Sector Wind                                 '
#  'Residential Biomass Wood                          '
#  'Residential Coal                                  '
#  'Residential Electricity                           '
#  'Residential Gas South Africa                      '
#  'Residential Oil Kerosene                          '
#  'Residential Oil LPG                               '
#  'Transport Electricity                             '
#  'Transport Gas South Africa                        '
#  'Transport Hydrogen                                '
#  'Transport Oil Av Gasoline                         '
#  'Transport Oil Diesel                              '
#  'Transport Oil Gasoline                            '
#  'Transport Oil HFO                                 '
#  'Transport Oil Kerosene                            '
#  'Supply Sector Coal low grade                      '
#  'Supply Sector Electricity                         '
#  'Supply Sector Gas South Africa                    '
#  'Supply Sector Coastal Gas                         '
#  'Supply Sector Oil Crude                           ']
#
#  --------------------------------########################--------------------
#
#
# IPCC_Category_L1  unique values:
#  [nan '2 Industrial Processes and Product Use ' '3 AFOLU' '4 Waste'
#  '1 Energy']
#
#  --------------------------------########################--------------------
#
#
# IPCC_Category_L2  unique values:
#  [nan '2A Mineral Industry' '2B Chemical Industry' '2C Metal Industry'
#  '2D Non-energy products from fuels and solvent use'
#  '2F Product uses as substitutes for ozone depleting substances'
#  '3A Livestock' '3B Land' '3C Aggregated and non-CO2 emisisons from land'
#  '3D Other' '4A Solid Waste Disposal'
#  '4B Biological treatment of solid waste' '4C2 Open Burning of Waste'
#  '4D1 Wastewater Treatment and Discharge' '1A Fuel Combustion Activities'
#  0 '1B Fugitive Emissions from Fuels']
#
#  --------------------------------########################--------------------
#
#
# IPCC_Category_L3  unique values:
#  [nan '2A1 Cement Production' '2A3 Glass Production'
#  '2B2 Nitric Acid Production' '2B5 Carbide Production'
#  '2B6 Titanium Dioxide Production' '2B8 Carbon Black Production'
#  '2C1 Iron and Steel Production' '2C2 Ferroalloys production'
#  '2C3 Aluminium Production' '2C5 Lead Production' '2C6 Zinc Production'
#  '2D1 Lubricant use' '2D2 Paraffin Wax Use'
#  '2F1 Refrigeration and Air Conditioning' '2F2 Foam blowing agents'
#  '2F3 Fire protection' '2F4 Aerosols' '3A1 Enteric fermentation'
#  '3A2 Manure management' '3B1 Forest land' '3B1 Forest land '
#  '3B2 Cropland ' '3B3 Grassland ' '3B3 Grassland' '3B4 Wetland (CH4)'
#  '3B5 Settlements' '3B6 Other lands' '3C1 Biomass burning' '3C2 Liming'
#  '3C3 Urea application ' '3C4 Direct N2O from managed soils (N2O)'
#  '3C5 Indirect N2O from managed soils (N2O)'
#  '3C6 Indirect N2O from manure management (N2O)'
#  '3D1 Harvested wood products' '4A Solid Waste Disposal'
#  '4B Biological treatment of solid waste' '4C2 Open Burning of Waste'
#  '4D1 Wastewater Treatment and Discharge' '1A4 Other Sectors'
#  '1A1 Energy Industries' '1A2 Manufacturing Industries and Construction' 0
#  '1B1 Solid Fuels' '1B2 Oil and Natural Gas' '1A3 Transport'
#  '1B3 Other Emissions']
#
#  --------------------------------########################--------------------
#
#
# IPCC_Category_L4  unique values:
#  [nan '2A1 Cement Production' '2A3 Glass Production'
#  '2B2 Nitric Acid Production' '2B5 Carbide Production'
#  '2B6 Titanium Dioxide Production' '2B8 Carbon Black Production'
#  '2C1 Iron and Steel Production' '2C2 Ferroalloys production'
#  '2C3 Aluminium Production' '2C5 Lead Production' '2C6 Zinc Production'
#  '2D1 Lubricant use' '2D2 Paraffin Wax Use'
#  '2F1 Refrigeration and Air Conditioning' '2F2 Foam blowing agents'
#  '2F3 Fire protection' '2F4 Aerosols' '3A1a Cattle' '3A1c Sheep'
#  '3A1d Goats' '3A1f Horses' '3A1g Mules and asses' '3A1h Swine'
#  '3A2a Cattle' '3A2c Sheep' '3A2d Goats' '3A2f Horses'
#  '3A2g Mules and asses' '3A2h Swine' '3A2i Poultry'
#  '3B1a Forest land remaining forest land'
#  '3B1b Land converted to forest land' '3B2a Cropland remaining cropland'
#  '3B2b Land converted to cropland' '3B3a Grassland remaining grassland'
#  '3B3b Land converted to grassland' '3B4 Wetland (CH4)'
#  '3B5a Settlements remaining settlements'
#  '3B5b Land converted to settlements' '3B6b Land converted to other land'
#  '3C1a Biomass burning in forest land' '3C1b Biomass burning in Croplands'
#  '3C1c Biomass burning in Grasslands' '3C1d Biomass burning in Wetlands'
#  '3C1e Biomass burning in Settlements' '3C2 Liming'
#  '3C3 Urea application ' '3C4 Direct N2O from managed soils (N2O)'
#  '3C5 Indirect N2O from managed soils (N2O)'
#  '3C6 Emissions due to volatilization' '3D1 Harvested wood products'
#  '4A Solid Waste Disposal' '4B Biological treatment of solid waste'
#  '4C2 Open Burning of Waste' '4D1 Wastewater Treatment and Discharge'
#  '1A4c Agriculture/Forestry/Fishing/Fish Farms'
#  '1A4a Commercial/Institutional' '1A1a Electricity and Heat Production'
#  '1A2c Chemicals'
#  '1A1c Manufacture of solid fuels and other energy industries' 0
#  '1A2b Non-Ferrous Metals' '1A2a Iron and Steel'
#  '1A2e Food Processing, Beverages and Tobacco' '1A2i Mining'
#  '1A2f Non-Metallic Minerals' '1A2m Non-specified Industry'
#  '1A2d Pulp, Paper and Print' '1B1a Mining' '1B2a Oil' '1A4b Residential'
#  '1A3a Transport - Aviation' '1A3b Transport - Road'
#  '1A3c Transport - Railways' '1A3d Transport - Water borne navigation'
#  '1B3 Other Emissions - Sasol' '1B3 Other Emissions - Petro SA'
#  '1A1b Petroleum refining ' '1B2 Oil and Natural Gas']
#
#  --------------------------------########################--------------------
#
#
# Description  unique values:
#  ['CO2 Captured                                      '
#  'Industry Process emissions CF4'
#  'Agriculture Coal                                  '
#  'Agriculture Oil Diesel                            '
#  'Agriculture Oil HFO                               '
#  'Agriculture Oil Kerosene                          '
#  'Agriculture Oil LPG                               '
#  'Biomass bagasse                                   '
#  'Biomass Other                                     '
#  'Biomass Wood                                      '
#  'Commercial - Space Heating                        '
#  'Commercial - Cooking                              '
#  'Commercial - Other                                '
#  'Commercial - Water Heating                        '
#  'Industry Process emissions CF6' 'Combustion CH4 South Africa'
#  'CH4S South Africa                                 '
#  'Fugitive Emissions South Africa                   '
#  'Coal Discard                                      '
#  'Coal low grade                                    '
#  'Combustion CO2 South Africa'
#  'CO2EQS South Africa                               '
#  'CO2S South Africa                                 '
#  'Process Emissions South Africa                    '
#  'Process Emissions Cement South Africa                    '
#  'Combustion Emissions - CEM South Africa'
#  'Process Emissions FerroChrome South Africa        '
#  'Process Emissions FerroManganese South Africa     '
#  'Transported and Stored CO2                        '
#  'Coal                                              '
#  'Commercial - Coal                                 '
#  'Commercial - Gas                                  '
#  'Commercial - Oil Diesel                           '
#  'Commercial - Oil Gasoline                         '
#  'Commercial - Oil HFO                              '
#  'Commercial - Oil Paraffin                         '
#  'Commercial - Oil LPG                              '
#  'Gas South Africa                                  '
#  'Gas Indigenous Ibhubezi                           '
#  'Coastal Gas                                       '
#  'Gas Indigenous Shale                              '
#  'Gas Methane Rich                                  '
#  'Gas Regional LNG                                  '
#  'Gas Southern Mozambique                           '
#  'Heat-Steam Existing                               '
#  'Heat-Steam New                                    '
#  'Hydrogen                                          '
#  'Industry - Aluminium Metal                        '
#  'Ammonia Demand Domestic Market                    '
#  'Industry-Chemicals-boiler/process heating - Waste '
#  'Industry-Chemicals-Ancillary - Gas - Existing     '
#  'Industry - Ferro Alloy Metals production          ' 'Industry - Biochar'
#  'Industry-Food, Beverage & Tabacco-boiler/process h'
#  'Industry - Iron and Steel - Coke                  '
#  'Industry - Crude Steel                            '
#  'Industry - Iron and Steel - Iron Ore              '
#  'Industry - Hot Bricketted Iron - HDRI route       '
#  'Industry - hydrogen for steel - steel commodity   '
#  'Hydrogen for HDRI iron and steel                  '
#  'Industry-Mining-Transport - Oil Diesel - Existing '
#  'Industry-Mining-boiler/process heating - Waste - E'
#  'Industry - Biomass Bagasse                        '
#  'Industry - Biomass wood                           '
#  'Industry-Low Grade Coal                           '
#  'Industry Coal for Material Use'
#  'Industry - Coal                                   '
#  'Industry - South Africa gas                       '
#  'Industry Gas Material Use'
#  'Industry Hydrogen                                 '
#  'Industry - Oil Diesel                             '
#  'Industry - Oil HFO                                '
#  'Industry - Oil LPG                                '
#  'Industry Oil HFO for material use'
#  'Industry - Waste                                  '
#  'Industry - Waste - material use                 '
#  'Industry-Precious & Non-Ferrous metals-boiler/proc'
#  'Industry - Non-metallic minerals - Bricks and cera'
#  'Industry - Non-metallic minerals                  '
#  'Industry - Non-metallic Minerals - Cement - Therma'
#  'Industry - Non-metallic Minerals - Clinker        '
#  'Cement sector clinker substitute                  '
#  'Industry - Non-metallic minerals - Glass          '
#  'Industry - Non-metallic minerals - Lime           '
#  'Industry - Non-metallic Minerals - Raw materials  '
#  'Industry-Other-Transport - Oil Diesel - Existing  '
#  'Industry-Other-boiler/process heating - Waste - Ex'
#  'Industry - demand for PGMS - Pt' 'Industry - PGMs - Platinum'
#  'Industry - Other PGMs'
#  'Industry - Pulp and Paper - Biomass               '
#  'Industry - Pulp and Paper - Black liquor          '
#  'Industry - Pulp and paper - Oil Heavy fuel        '
#  'Industry - Pulp and paper                         '
#  'Industry - Pulp&Paper - Pulp                      '
#  'Industry - Pulp&Paper - Pulp dissolving           '
#  'Industry - Pulp&Paper - Steam                     '
#  'Methanol                                          '
#  'N2OS South Africa                                 '
#  'Ammonia                                           ' 'Green Ammonia'
#  'Nuclear                                           '
#  'Oil Av Gasoline                                   '
#  'Oil Crude                                         '
#  'Oil Diesel                                        '
#  'Oil Gasoline                                      '
#  'Oil HFO                                           '
#  'Oil Kerosene                                      '
#  'Oil Green Jet Fuel                                      '
#  'Oil LPG                                           '
#  'Power Sector Biogas                               '
#  'Power Sector Biomass Other                        '
#  'Power Sector Coal Discard                         '
#  'Power Sector Coal low grade                       '
#  'Coal for ARNOT Power Plant' 'Coal for CAMDEN Power Plant'
#  'Coal for DUVHA Power Plant' 'Coal for GROOTVLEI Power Plant'
#  'Coal for HENDRINA Power Plant' 'Coal for KENDAL Power Plant'
#  'Coal for KOMATI Power Plant' 'Coal for KRIEL Power Plant'
#  'Coal for KUSILE Power Plant' 'Coal for LETHABO Power Plant'
#  'Coal for MAJUBA DRY Power Plant' 'Coal for MATIMBA Power Plant'
#  'Coal for MATLA Power Plant' 'Coal for MEDUPI Power Plant'
#  'Coal for TUTUKA Power Plant'
#  'Power Sector Gas South Africa                     '
#  'Power Sector Coastal Gas                          '
#  'Power Sector Hydrogen                             '
#  'Power Sector Hydro                                '
#  'Power Sector Nuclear                              '
#  'Power Sector Oil Diesel                           '
#  'Power Sector Oil HFO                    '
#  'Power Sector Oil Kerosene                         '
#  'Power Sector Solar                                '
#  'Power Sector Wind                                 '
#  'Power Sector Water                '
#  'Residential - Biomass Wood                        '
#  'Residential - Coal                                '
#  'Residential - Natural gas                         '
#  'Residential - Oil Paraffin                        '
#  'Residential - Oil LPG                             '
#  'Transport Other -  Aviation Dom Jet Fuel          '
#  'Transport Other -  Aviation Int Jet Fuel          '
#  'Transport Other - Aviation Gasoline               '
#  'Transport Freight - HCV1                          '
#  'Transport Freight - HCV2                          '
#  'Transport Freight - HCV3                          '
#  'Transport Freight - HCV4                          '
#  'Transport Freight - HCV5                          '
#  'Transport Freight - HCV6                          '
#  'Transport Freight - HCV7                          '
#  'Transport Freight - HCV8                          '
#  'Transport Freight - HCV9                          '
#  'Transport Freight - LCV                           '
#  'Transport Other - Pipeline                        '
#  'Transport Freight - Rail Corridor                 '
#  'Transport Freight - Rail Export (bulk mining)     '
#  'Transport Freight - Rail Other                    '
#  'Transport Passenger Car Priv.Veh.                 '
#  'Transport Passenger Moto Priv.Veh.                '
#  'Transport Passenger SUV Priv.Veh.                 '
#  'Transport Passenger BRT                           '
#  'Transport Passenger Bus                           '
#  'Transport Passenger Gautrain                      '
#  'Transport Passenger Minibus                       '
#  'Transport Passenger Metro Rail                    '
#  'Transport Gas South Africa                        '
#  'Transport Hydrogen                                '
#  'Transport Oil Av Gasoline                         '
#  'Transport Oil Diesel                              '
#  'Transport Oil Gasoline                            '
#  'Transport Oil HFO                                 '
#  'Transport Oil Kerosene                            '
#  'Transport Other - HFO                             '
#  'Supply Sector Coal low grade                      '
#  'Supply Sector Gas South Africa                    '
#  'Supply Sector Coastal Gas                         '
#  'Supply Sector Heat-Steam Existing                 '
#  'Supply Sector Heat-Steam New                      '
#  'Supply Sector Oil Crude                           '
#  'Waste                                             ' 'Y'
#  'Agriculture - Heating                             '
#  'CMOX South Africa                                 '
#  'NMVS South Africa                                 '
#  'NOXS South Africa                                 ' 'PM10 South Africa'
#  'SOXS South Africa                                 '
#  'Agriculture Electricity                           '
#  'Agriculture - Irrigation                          '
#  'Agriculture - Other                               '
#  'Agriculture - Processing                          '
#  'Agriculture - Traction                            '
#  'Commercial - Cooling                              '
#  'Commercial - Electricity                          '
#  'Commercial - Public lights                        '
#  'Commercial - Lighting                             '
#  'Commercial - Refrigeration                        '
#  'Commercial - Public Water                         '
#  'Electricity Upstream Transmission                 '
#  'Industry-MI-Electricity                           '
#  'Industry Electricity                              '
#  'Residential - Electricity                         '
#  'Power Sector - Environmental Levy                 '
#  'Industry-CP-Electricity                           '
#  'Supply Sector Electricity                         '
#  'Electricity                                       '
#  'Industry-NF-Electricity                           '
#  'Industry-Chemicals-Compressed air - Electricity   '
#  'Industry-Chemicals-Cooling - Electricity          '
#  'Industry-Chemicals-Electrochemical - Electricity  '
#  'Industry-Chemicals-Fans - Electricity             '
#  'Industry-Chemicals-HVAC - Electricity             '
#  'Industry-Chemicals-Elec Heating - Electricity     '
#  'Industry-Chemicals-Lighting - Electricity         '
#  'Industry-Chemicals-Other motive - Electricity     '
#  'Industry-Chemicals-Pumping - Electricity          '
#  'Industry-FA-Electricity                           '
#  'Industry-Food, Beverage & Tabacco-Compressed air -'
#  'Industry-FB-Electricity                           '
#  'Industry-Food, Beverage & Tabacco-Cooling - Electr'
#  'Industry-Food, Beverage & Tabacco-Fans - Electrici'
#  'Industry-Food, Beverage & Tabacco-HVAC - Electrici'
#  'Industry-Food, Beverage & Tabacco-Elec Heating - E'
#  'Industry-Food, Beverage & Tabacco-Lighting - Elect'
#  'Industry-Food, Beverage & Tabacco-Other motive - E'
#  'Industry-Food, Beverage & Tabacco-Pumping - Electr'
#  'Industry - iron and steel BF slag'
#  'Industry-IS-Electricity                           '
#  'Industry-Mining-Compressed air - Electricity      '
#  'Industry-Mining-Cooling - Electricity             '
#  'Industry-Mining-Electrochemical - Electricity     '
#  'Industry-Mining-Fans - Electricity                '
#  'Industry-Mining-HVAC - Electricity                '
#  'Industry-Mining-Elec Heating - Electricity        '
#  'Industry-Mining-Lighting - Electricity            '
#  'Industry-Mining-Other motive - Electricity        '
#  'Industry-Mining-Pumping - Electricity             '
#  'Industry-Precious & Non-Ferrous metals-Electrochem'
#  'Industry-Precious & Non-Ferrous metals-HVAC - Elec'
#  'Industry-Precious & Non-Ferrous metals-Elec Heatin'
#  'Industry-Precious & Non-Ferrous metals-Lighting - '
#  'Industry-Precious & Non-Ferrous metals-Other motiv'
#  'Industry-NM-Electricity                           '
#  'Industry-Other-Compressed air - Electricity       '
#  'Industry-OT-Electricity                           '
#  'Industry-Other-Cooling - Electricity              '
#  'Industry-Other-Electrochemical - Electricity      '
#  'Industry-Other-Fans - Electricity                 '
#  'Industry-Other-HVAC - Electricity                 '
#  'Industry-Other-Elec Heating - Electricity         '
#  'Industry-Other-Lighting - Electricity             '
#  'Industry-Other-Other motive - Electricity         '
#  'Industry-Other-Pumping - Electricity              '
#  'Industry-PP-Electricity                           '
#  'Industry - Pulp&Paper - Recycled paper            '
#  'Hydro                                             '
#  'Solar                                             '
#  'Wind                                              '
#  'dummy commodity for transmission dummy cost accoun'
#  'Residential - Space Heating - High Income Electrif'
#  'Residential - Cooking - High Income Electrified   '
#  'Residential - Lighting - High Income Electrified  '
#  'Residential - Other - High Income Electrified     '
#  'Residential - Refrigeration - High Income Electrif'
#  'Residential - Water Heating Geyser - High Income E'
#  'Residential - Space Heating - Low Income Electrifi'
#  'Residential - Cooking - Low Income Electrified    '
#  'Residential - Lighting - Low Income Electrified   '
#  'Residential - Lighting - Low Income Non-Electrifie'
#  'Residential - Other - Low Income Electrified      '
#  'Residential - Refrigeration - Low Income Electrifi'
#  'Residential - Water Heating - Low Income Electrifi'
#  'Residential - Space Heating - Middle Income Electr'
#  'Residential - Cooking - Middle Income Electrified '
#  'Residential - Lighting - Middle Income Electrified'
#  'Residential - Lighting - Middle Income Non-Electri'
#  'Residential - Other - Middle Income Electrified   '
#  'Residential - Refrigeration - Middle Income Electr' 0
#  'Residential - Water Heating Geyser - Middle Income'
#  'Transport Electricity                             '
#  'Oil Other                                         ']
#
#  --------------------------------########################--------------------
#
#
# Short Description  unique values:
#  ['CO2 Captured                                      ' 'CF4' 'Coal'
#  'Diesel' 'HFO' 'Kerosene' 'LPG' 'Biomass' 'Biowood' 0 'C2F6'
#  'Discard Coal' 'CO2                                   ' 'CO2EQ' 'CO2'
#  'CO2S' 'Transported and Stored CO2                        ' 'Gas'
#  'Gasoline' 'Heat' 'Hydrogen' 'Aluminium' 'Ammonia' 'FerroChrome Metal'
#  'BioChar' 'FerroManganese Metal' 'Coke' 'Iron and Steel' 'Iron Ore'
#  'Waste' 'Bricks and Ceramics' 'Cement' 'Thermal (Cement)'
#  'Clinker (Cement)' 'Cement sector clinker substitute                  '
#  'Glass' 'Lime' 'PGM' 'Steam' 'Methanol' 'Nuclear' 'Aviation Gasoline'
#  'Crude Oil' 'Green Jet Fuel' 'Biogas' 'Hydro' 'Solar' 'WND' 'Water'
#  'CMOX' 'PM10' 'Electricity' 'BF slag' 'Other liquid fuels']
#
#  --------------------------------########################--------------------
#
#
# Commodity_Name  unique values:
#  [0 'CF4' 'Coal' 'Diesel' 'Residual Fuel Oil (HFO)' 'Kerosene' 'LPG'
#  'Other primary solid biomass' 'Wood/Wood Waste' 'C2F6' 'Gas'
#  'Motor gasoline' 'Aluminium' 'Ammonia' 'FerroChrome Metal' 'BioChar'
#  'Petroleum coke' 'Iron and Steel' 'Iron Ore' 'Hydrogen' 'HFO'
#  'Cement sector clinker substitute                  ' 'Aviation gasoline'
#  'Water' 'PM10' 'Electricity' 'BF slag' 'Bitumen']
#
#  --------------------------------########################--------------------

# %%
report_df = merged_df

# Instantiate df list
filtered_dfs = []
i = 1
# Iterate through each row in filter_df and filter report_df
for _, row in filter_df.iterrows():
    filtered_dfs.append(filter_data(row))
    

# Concatenate all dataframes in filtered_dfs to get a single dataframe
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Export 
# final_df.to_csv('input/results_filter.csv', index = False)

final_df.reset_index(drop=True, inplace=True)
# Out:
# Filter ["Commodity is in ['COMOLP', 'COMOKE', 'COMOHF', 'COMODS', 'COMOGS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Space Heating']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMOLP', 'COMOKE', 'COMOHF', 'COMODS', 'COMOGS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooking']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']", "Subsubsector is in ['Lighting']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMOLP', 'COMOKE', 'COMOHF', 'COMODS', 'COMOGS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Space Heating']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMOLP', 'COMOKE', 'COMOHF', 'COMODS', 'COMOGS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooking']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']", "Subsubsector is in ['Lighting']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMOLP', 'COMOKE', 'COMOHF', 'COMODS', 'COMOGS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Space Heating']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMOLP', 'COMOKE', 'COMOHF', 'COMODS', 'COMOGS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooking']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Commerce']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']", "Subsubsector is in ['Lighting']"] resulted in empty dataframe.
# Filter ["Commodity is in ['COMELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Commerce']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Sector is in ['Population']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['pkm']", "Sector is in ['Transport']", "Subsubsector is in ['TraOther']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['pkm']", "Sector is in ['Transport']", "Subsector is in ['Aviation-Domestic', 'Aviation-International']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['Capacity']", "Sector is in ['Transport']", "Subsubsector is in ['CarHydrogen', 'SUVHydrogen']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['NewCapacity']", "Sector is in ['Transport']", "Subsubsector is in ['CarHydrogen', 'SUVHydrogen']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['Activity']", "Sector is in ['Transport']", "Subsubsector is in ['CarHydrogen', 'SUVHydrogen']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Transport']", "Subsubsector is in ['CarHydrogen', 'SUVHydrogen']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Transport']", "Subsubsector is in ['BusElectric', 'BRTElc']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Transport']", "Subsubsector is in ['MinibusElectric', 'MinibusHybrid']"] resulted in empty dataframe.
# Filter ["Commodity is in ['TRAHGN']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Transport']", "Subsector is in ['PassPub', 'PassPriv', 'TraOther', 'Aviation-Domestic', 'Aviation-International']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Transport']", "Subsubsector is in ['PassengerRail']"] resulted in empty dataframe.
# Filter ["Commodity is in ['TRAGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Transport']", "Subsubsector is in ['CarOil', 'CarElectric', 'CarHybrid', 'CarGas', 'CarHydrogen', 'CarFlex', 'SUVOil', 'SUVElectric', 'SUVHybrid', 'SUVGas', 'SUVHydrogen', 'SUVFlex']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Transport']", "Subsubsector is in ['CarFlex', 'SUVFlex']"] resulted in empty dataframe.
# Filter ["Commodity is in ['TRABGS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Transport']"] resulted in empty dataframe.
# Filter ["Commodity is in ['TRAELC', 'TRAHGN']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Transport']"] resulted in empty dataframe.
# Filter ["Commodity is in ['P10S']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowOut']", "Sector is in ['Transport']", "Subsector is in ['PassPub', 'PassPriv', 'TraOther', 'Aviation-Domestic', 'Aviation-International']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['pkm']", "Sector is in ['Transport']", "Subsector is in ['TraOther', 'Aviation-International']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['pkm']", "Sector is in ['Transport']", "Subsector is in ['TraOther']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['pkm']", "Sector is in ['Transport']", "Subsector is in ['Aviation-International']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CH4', 'N2O']", "Sector is in ['Transport']", "Subsector is in ['Aviation-International']"] resulted in empty dataframe.
# Filter ["Commodity is in ['NOXS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowOut']", "Sector is in ['Transport']", "Subsector is in ['PassPub', 'PassPriv', 'TraOther', 'Aviation-Domestic', 'Aviation-International']", "Subsubsector is in ['CarFlex', 'SUVFlex', 'BusFlex', 'BRTFlex']"] resulted in empty dataframe.
# Filter ["Commodity is in ['NOXS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowOut']", "Sector is in ['Transport']", "Subsector is in ['PassPub', 'PassPriv', 'TraOther', 'Aviation-Domestic', 'Aviation-International']", "Subsubsector is in ['BusHydrogen', 'BRTHydrogen', 'MinibusHydrogen', 'CarHydrogen', 'SUVHydrogen']"] resulted in empty dataframe.
# Filter ["Commodity is in ['NOXS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowOut']", "Sector is in ['Transport']", "Subsubsector is in ['PassengerRail']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['Activity']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESOLP', 'RESOKE']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESOLP', 'RESOKE']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['Activity']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESOLP', 'RESOKE']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESOLP', 'RESOKE']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['Activity']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESOLP', 'RESOKE']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESOLP', 'RESOKE']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESGAS']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESCOA']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['FlowIn']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']", "Subsubsector is in ['Cooling']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']", "Subsubsector is in ['Other']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESELC']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']"] resulted in empty dataframe.
# Filter ["Commodity is in ['RESBIW']", 'Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Indicator is in ['CO2']", "Sector is in ['Residential']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2099B_99NESSNXCT-IMG', "Sector is in ['Population']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_08EESSNXCT_IMG', "Sector is in ['Population']"] resulted in empty dataframe.
# Filter ['Year is in [2020, 2030, 2040, 2050]', 'Scenario == NZ10_2050A_09EESSNXCT-IMG', "Sector is in ['Population']"] resulted in empty dataframe.

# %%
final_df
# Out:
#               Process Commodity  Year                   Scenario Indicator  \
# 0         CECELCCEN-E    ACTGRP  2020  NZ10_2099B_99NESSNXCT-IMG  Activity
# 1         CECELCCEN-E    ACTGRP  2030  NZ10_2099B_99NESSNXCT-IMG  Activity
# 2         CECELCCEN-E    ACTGRP  2040  NZ10_2099B_99NESSNXCT-IMG  Activity
# 3         CECELCCEN-E    ACTGRP  2050  NZ10_2099B_99NESSNXCT-IMG  Activity
# 4         CECELCCEN-N    ACTGRP  2030  NZ10_2099B_99NESSNXCT-IMG  Activity
# ...               ...       ...   ...                        ...       ...
# 8861  RMEWOLPKETLPG-E    RESOLP  2030  NZ10_2050A_09EESSNXCT-IMG       N2O
# 8862  RMEWOLPKETLPG-E    RESOLP  2040  NZ10_2050A_09EESSNXCT-IMG       CH4
# 8863  RMEWOLPKETLPG-E    RESOLP  2040  NZ10_2050A_09EESSNXCT-IMG       N2O
# 8864  RMEWOLPKETLPG-E    RESOLP  2050  NZ10_2050A_09EESSNXCT-IMG       CH4
# 8865  RMEWOLPKETLPG-E    RESOLP  2050  NZ10_2050A_09EESSNXCT-IMG       N2O
#
#            Sector     Subsector   Subsubsector  \
# 0        Commerce   ComExisting        Cooling
# 1        Commerce   ComExisting        Cooling
# 2        Commerce   ComExisting        Cooling
# 3        Commerce   ComExisting        Cooling
# 4        Commerce   ComExisting        Cooling
# ...           ...           ...            ...
# 8861  Residential  MiddleIncome  Water Heating
# 8862  Residential  MiddleIncome  Water Heating
# 8863  Residential  MiddleIncome  Water Heating
# 8864  Residential  MiddleIncome  Water Heating
# 8865  Residential  MiddleIncome  Water Heating
#
#                                         TechDescription IPCC_Category_L1  \
# 0     Commercial - Cooling - Electricity - Central -...         1 Energy
# 1     Commercial - Cooling - Electricity - Central -...         1 Energy
# 2     Commercial - Cooling - Electricity - Central -...         1 Energy
# 3     Commercial - Cooling - Electricity - Central -...         1 Energy
# 4     Commercial - Cooling - Electricity - Central -...         1 Energy
# ...                                                 ...              ...
# 8861  Residential - Water Heating - Middle Income El...         1 Energy
# 8862  Residential - Water Heating - Middle Income El...         1 Energy
# 8863  Residential - Water Heating - Middle Income El...         1 Energy
# 8864  Residential - Water Heating - Middle Income El...         1 Energy
# 8865  Residential - Water Heating - Middle Income El...         1 Energy
#
#                    IPCC_Category_L2   IPCC_Category_L3  \
# 0     1A Fuel Combustion Activities  1A4 Other Sectors
# 1     1A Fuel Combustion Activities  1A4 Other Sectors
# 2     1A Fuel Combustion Activities  1A4 Other Sectors
# 3     1A Fuel Combustion Activities  1A4 Other Sectors
# 4     1A Fuel Combustion Activities  1A4 Other Sectors
# ...                             ...                ...
# 8861  1A Fuel Combustion Activities  1A4 Other Sectors
# 8862  1A Fuel Combustion Activities  1A4 Other Sectors
# 8863  1A Fuel Combustion Activities  1A4 Other Sectors
# 8864  1A Fuel Combustion Activities  1A4 Other Sectors
# 8865  1A Fuel Combustion Activities  1A4 Other Sectors
#
#                    IPCC_Category_L4  \
# 0     1A4a Commercial/Institutional
# 1     1A4a Commercial/Institutional
# 2     1A4a Commercial/Institutional
# 3     1A4a Commercial/Institutional
# 4     1A4a Commercial/Institutional
# ...                             ...
# 8861               1A4b Residential
# 8862               1A4b Residential
# 8863               1A4b Residential
# 8864               1A4b Residential
# 8865               1A4b Residential
#
#                                             Description Short Description  \
# 0                                                     Y                 0
# 1                                                     Y                 0
# 2                                                     Y                 0
# 3                                                     Y                 0
# 4                                                     Y                 0
# ...                                                 ...               ...
# 8861  Residential - Oil LPG                         ...               LPG
# 8862  Residential - Oil LPG                         ...               LPG
# 8863  Residential - Oil LPG                         ...               LPG
# 8864  Residential - Oil LPG                         ...               LPG
# 8865  Residential - Oil LPG                         ...               LPG
#
#      Commodity_Name    SATIMGE  UniqueID
# 0                 0  84.296274   1_18_38
# 1                 0  66.127038   1_18_38
# 2                 0  24.237112   1_18_38
# 3                 0   0.672616   1_18_38
# 4                 0  23.578447   1_18_38
# ...             ...        ...       ...
# 8861            LPG   0.073736  3_16_133
# 8862            LPG   0.140180  3_16_133
# 8863            LPG   0.044224  3_16_133
# 8864            LPG   0.005343  3_16_133
# 8865            LPG   0.001686  3_16_133
#
# [8866 rows x 18 columns]

# %%
# Initialize an empty list
cumulativeIDs = []

# Loop through N values
for N in [1, 2, 3]:
    # Loop through M values
    for M in range(109, 124):  # This will loop from 127 to 143 inclusive
        # Construct the string using the pattern and append to the list
        cumulativeIDs.append(f"{N}_24_{M}") # 24 = power tab. 
        
# Print the list
print(cumulativeIDs)
# Out:
# ['1_24_109', '1_24_110', '1_24_111', '1_24_112', '1_24_113', '1_24_114', '1_24_115', '1_24_116', '1_24_117', '1_24_118', '1_24_119', '1_24_120', '1_24_121', '1_24_122', '1_24_123', '2_24_109', '2_24_110', '2_24_111', '2_24_112', '2_24_113', '2_24_114', '2_24_115', '2_24_116', '2_24_117', '2_24_118', '2_24_119', '2_24_120', '2_24_121', '2_24_122', '2_24_123', '3_24_109', '3_24_110', '3_24_111', '3_24_112', '3_24_113', '3_24_114', '3_24_115', '3_24_116', '3_24_117', '3_24_118', '3_24_119', '3_24_120', '3_24_121', '3_24_122', '3_24_123']

# %%
file_names = ['input/WB1.xlsx', 'input/WB2.xlsx', 'input/WB3.xlsx']

# Predefined year_to_column mapping.
year_to_column = {2020: 4, 2030: 5, 2040: 6, 2050: 7, 2060: 8}

# Aggregate the data by UniqueID and Year, summing SATIMGE values.
aggregated = final_df.groupby(['UniqueID', 'Year'])['SATIMGE'].sum().reset_index()

# Define the range of 'certain years'.
start_year = 2020  # adjust accordingly
end_year = 2060    # adjust accordingly

# Filter out the special rows using the cumulativeIDs list.
special_rows = aggregated[aggregated['UniqueID'].isin(cumulativeIDs)]

# For these special rows, compute cumulative sums in ten-year steps.
cumulative_sums = []

for unique_id in cumulativeIDs:
    subset = special_rows[special_rows['UniqueID'] == unique_id]
    for year in range(start_year, end_year, 10):
        end = year + 10
        total_sum = subset[(subset['Year'] >= year) & (subset['Year'] < end)]['SATIMGE'].sum()
        cumulative_sums.append((unique_id, year, total_sum))

# Convert the result into a DataFrame.
cumulative_df = pd.DataFrame(cumulative_sums, columns=['UniqueID', 'StartYear', 'CumulativeSATIMGE'])

# %%
cumulative_df.head(200)
# Out:
#      UniqueID  StartYear  CumulativeSATIMGE
# 0    1_24_109       2020                0.0
# 1    1_24_109       2030                0.0
# 2    1_24_109       2040                0.0
# 3    1_24_109       2050                0.0
# 4    1_24_110       2020                0.0
# ..        ...        ...                ...
# 175  3_24_122       2050                0.0
# 176  3_24_123       2020                0.0
# 177  3_24_123       2030                0.0
# 178  3_24_123       2040                0.0
# 179  3_24_123       2050                0.0
#
# [180 rows x 3 columns]

# %%
aggregated = pd.merge(aggregated, Units, on='UniqueID', how='left')

# %%
# Conversion factors to convert everything to 'm' (for example)
conversion_factors = {
    'Mt': 0.001, #units in model for emissions are already kt.
    'USD': 1/12.94, # to 2015 USD
    'kt': 1, #all emissions are in kt
    'GW': 1, 
    'TWh': 1/3.6, #PJ to TWh
    'EJ': 0.001, #PJ to EJ
    '*': 1,
    '': 1,
    'million inhab': 0.001,
    'gas_Nm3': 25641025,#Nm3 of NGas per PJ. convert PJ of NGas to nM3 of gas    
    'crude_Mt':1/42, #Mt of Ngas per PJ. convert PJ of crude oil to Mt of crude oil
    'biomass_Mt':1/16, #Mt of biomass per PJ. based on 16MJ/kg convert PJ of biomass to Mt of biomass
    'H2_Nm':78740157, #Nm3 per PJ. convert PJ of hydrogen to Nm3
    'Mio' : 0.001,
    'pkm' : 0.000001, #bpkm default unit in the model
    'Gvkm' : 1, #bvkm default unit in the model

    
}

aggregated['SATIMGE'] = aggregated.apply(convert_value, axis=1)

# %%
type(conversion_factors)
# Out:
# dict

# %%
decades = list(range(start_year, end_year, 10))  # Adjust as per your requirement
cumulative_sums = {}

for unique_id, group in aggregated.groupby('UniqueID'):
    if unique_id in cumulativeIDs:
        decade_sums = {}
        
        for start_year in decades:
            end_year = start_year + 10
            decade_data = group[(group['Year'] >= start_year) & (group['Year'] < end_year)]
            decade_sums[start_year] = decade_data['SATIMGE'].sum()
        
        cumulative_sums[unique_id] = decade_sums

# Print out some of the cumulative_sums for debugging
for key, value in list(cumulative_sums.items())[:5]:
    print(key, value)

# %%
# 
aggregated = aggregated[~aggregated['UniqueID'].isin(cumulativeIDs)] #tilda is negation. aggregated NOT in...
aggregated = aggregated[aggregated['Year'].isin([2020,2030,2040,2050,2060,2070])]

# %%
Units['UniqueID']
# Out:
# 0       1_18_38
# 1       1_18_40
# 2       1_18_41
# 3       1_18_42
# 4       1_18_43
#          ...
# 384    3_16_130
# 385    3_16_133
# 386     1_16_19
# 387     2_16_19
# 388     3_16_19
# Name: UniqueID, Length: 389, dtype: object

# %%
decade_to_column = {
    2020: 4,
    2030: 5,
    2040: 6,
    2050: 7,
    2060: 8,
    2070: 9,
    # Adjust as needed
}

BASE_COLUMN = 4  # Adjust as needed

grouped = aggregated.groupby(['UniqueID'])

for (unique_id_string,), group in grouped:
    workbook_id, sheet_id, row_id = map(int, unique_id_string.split('_'))
    print(f"processing workbook {workbook_id}, sheet {sheet_id}, row {row_id}")

    # Use the workbook_id to select the correct workbook filename
    if 0 < workbook_id <= len(file_names):
        file_name = file_names[workbook_id - 1]  # Adjust for 0-based indexing
    else:
        raise ValueError(f"Workbook ID {workbook_id} is out of range.")
    
    try:
        book = load_workbook(file_name)
    except FileNotFoundError:
        print(f"File {file_name} not found. Skipping to the next file.")
        continue

    sheet_names = book.sheetnames
    if 0 <= sheet_id - 1 < len(sheet_names):
        sheet_name = sheet_names[sheet_id - 1]
        sheet = book[sheet_name]
    else:
        raise ValueError(f"Sheet ID {sheet_id} is out of range for workbook {file_name}.")

    # Check if the unique_id_string is in the special rows
    # Check if the unique_id_string is in the special rows and exists in cumulative_sums
    if unique_id_string in cumulativeIDs and unique_id_string in cumulative_sums:
            print(f'Entering cumulative logic for {unique_id_string}')
            for decade_start, sum_val in cumulative_sums[unique_id_string].items():
                column_index = decade_to_column[decade_start]
                sheet.cell(row=row_id, column=column_index, value=sum_val)
    else:
        # print(f'Entering non-cumulative logic for {unique_id_string}')
        for _, row in group.iterrows():
            if row['Year'] in year_to_column:
                column_index = year_to_column[row['Year']]
                sheet.cell(row=row_id, column=column_index, value=row['SATIMGE'])
            else:
                print(f"Warning: Year {row['Year']} not in year_to_column for unique_id_string {unique_id_string}")

    book.save(file_name)


print("Done")
# Out:
# processing workbook 1, sheet 16, row 102
# processing workbook 1, sheet 16, row 103
# processing workbook 1, sheet 16, row 104
# processing workbook 1, sheet 16, row 106
# processing workbook 1, sheet 16, row 110
# processing workbook 1, sheet 16, row 113
# processing workbook 1, sheet 16, row 115
# processing workbook 1, sheet 16, row 117
# processing workbook 1, sheet 16, row 118
# processing workbook 1, sheet 16, row 119
# processing workbook 1, sheet 16, row 122
# processing workbook 1, sheet 16, row 123
# processing workbook 1, sheet 16, row 124
# processing workbook 1, sheet 16, row 133
# processing workbook 1, sheet 16, row 38
# processing workbook 1, sheet 16, row 40
# processing workbook 1, sheet 16, row 42
# processing workbook 1, sheet 16, row 43
# processing workbook 1, sheet 16, row 44
# processing workbook 1, sheet 16, row 45
# processing workbook 1, sheet 16, row 47
# processing workbook 1, sheet 16, row 48
# processing workbook 1, sheet 16, row 49
# processing workbook 1, sheet 16, row 51
# processing workbook 1, sheet 16, row 55
# processing workbook 1, sheet 16, row 69
# processing workbook 1, sheet 16, row 70
# processing workbook 1, sheet 16, row 71
# processing workbook 1, sheet 16, row 73
# processing workbook 1, sheet 16, row 77
# processing workbook 1, sheet 16, row 80
# processing workbook 1, sheet 16, row 81
# processing workbook 1, sheet 16, row 82
# processing workbook 1, sheet 16, row 84
# processing workbook 1, sheet 16, row 88
# processing workbook 1, sheet 16, row 95
# processing workbook 1, sheet 18, row 102
# processing workbook 1, sheet 18, row 103
# processing workbook 1, sheet 18, row 104
# processing workbook 1, sheet 18, row 106
# processing workbook 1, sheet 18, row 113
# processing workbook 1, sheet 18, row 115
# processing workbook 1, sheet 18, row 117
# processing workbook 1, sheet 18, row 118
# processing workbook 1, sheet 18, row 120
# processing workbook 1, sheet 18, row 122
# processing workbook 1, sheet 18, row 123
# processing workbook 1, sheet 18, row 124
# processing workbook 1, sheet 18, row 133
# processing workbook 1, sheet 18, row 38
# processing workbook 1, sheet 18, row 40
# processing workbook 1, sheet 18, row 41
# processing workbook 1, sheet 18, row 42
# processing workbook 1, sheet 18, row 43
# processing workbook 1, sheet 18, row 44
# processing workbook 1, sheet 18, row 45
# processing workbook 1, sheet 18, row 48
# processing workbook 1, sheet 18, row 49
# processing workbook 1, sheet 18, row 51
# processing workbook 1, sheet 18, row 62
# processing workbook 1, sheet 18, row 69
# processing workbook 1, sheet 18, row 71
# processing workbook 1, sheet 18, row 73
# processing workbook 1, sheet 18, row 80
# processing workbook 1, sheet 18, row 81
# processing workbook 1, sheet 18, row 82
# processing workbook 1, sheet 18, row 84
# processing workbook 1, sheet 18, row 91
# processing workbook 1, sheet 18, row 92
# processing workbook 1, sheet 18, row 95
# processing workbook 1, sheet 8, row 105
# processing workbook 1, sheet 8, row 106
# processing workbook 1, sheet 8, row 107
# processing workbook 1, sheet 8, row 108
# processing workbook 1, sheet 8, row 109
# processing workbook 1, sheet 8, row 110
# processing workbook 1, sheet 8, row 111
# processing workbook 1, sheet 8, row 168
# processing workbook 1, sheet 8, row 172
# processing workbook 1, sheet 8, row 173
# processing workbook 1, sheet 8, row 174
# processing workbook 1, sheet 8, row 175
# processing workbook 1, sheet 8, row 178
# processing workbook 1, sheet 8, row 179
# processing workbook 1, sheet 8, row 180
# processing workbook 1, sheet 8, row 181
# processing workbook 1, sheet 8, row 185
# processing workbook 1, sheet 8, row 186
# processing workbook 1, sheet 8, row 187
# processing workbook 1, sheet 8, row 188
# processing workbook 1, sheet 8, row 191
# processing workbook 1, sheet 8, row 192
# processing workbook 1, sheet 8, row 193
# processing workbook 1, sheet 8, row 194
# processing workbook 1, sheet 8, row 199
# processing workbook 1, sheet 8, row 203
# processing workbook 1, sheet 8, row 205
# processing workbook 1, sheet 8, row 216
# processing workbook 1, sheet 8, row 218
# processing workbook 1, sheet 8, row 222
# processing workbook 1, sheet 8, row 224
# processing workbook 1, sheet 8, row 229
# processing workbook 1, sheet 8, row 230
# processing workbook 1, sheet 8, row 231
# processing workbook 1, sheet 8, row 232
# processing workbook 1, sheet 8, row 233
# processing workbook 1, sheet 8, row 236
# processing workbook 1, sheet 8, row 237
# processing workbook 1, sheet 8, row 238
# processing workbook 1, sheet 8, row 239
# processing workbook 1, sheet 8, row 240
# processing workbook 1, sheet 8, row 243
# processing workbook 1, sheet 8, row 245
# processing workbook 1, sheet 8, row 247
# processing workbook 1, sheet 8, row 249
# processing workbook 1, sheet 8, row 251
# processing workbook 1, sheet 8, row 254
# processing workbook 1, sheet 8, row 257
# processing workbook 1, sheet 8, row 263
# processing workbook 1, sheet 8, row 265
# processing workbook 1, sheet 8, row 267
# processing workbook 1, sheet 8, row 268
# processing workbook 1, sheet 8, row 269
# processing workbook 1, sheet 8, row 270
# processing workbook 1, sheet 8, row 271
# processing workbook 1, sheet 8, row 273
# processing workbook 1, sheet 8, row 277
# processing workbook 1, sheet 8, row 282
# processing workbook 1, sheet 8, row 283
# processing workbook 1, sheet 8, row 288
# processing workbook 1, sheet 8, row 289
# processing workbook 1, sheet 8, row 29
# processing workbook 1, sheet 8, row 291
# processing workbook 1, sheet 8, row 292
# processing workbook 1, sheet 8, row 305
# processing workbook 1, sheet 8, row 306
# processing workbook 1, sheet 8, row 31
# processing workbook 1, sheet 8, row 311
# processing workbook 1, sheet 8, row 312
# processing workbook 1, sheet 8, row 374
# processing workbook 1, sheet 8, row 375
# processing workbook 1, sheet 8, row 377
# processing workbook 1, sheet 8, row 383
# processing workbook 1, sheet 8, row 385
# processing workbook 1, sheet 8, row 386
# processing workbook 1, sheet 8, row 387
# processing workbook 1, sheet 8, row 388
# processing workbook 1, sheet 8, row 389
# processing workbook 1, sheet 8, row 41
# processing workbook 1, sheet 8, row 42
# processing workbook 1, sheet 8, row 44
# processing workbook 1, sheet 8, row 45
# processing workbook 1, sheet 8, row 46
# processing workbook 2, sheet 16, row 102
# processing workbook 2, sheet 16, row 103
# processing workbook 2, sheet 16, row 104
# processing workbook 2, sheet 16, row 106
# processing workbook 2, sheet 16, row 110
# processing workbook 2, sheet 16, row 113
# processing workbook 2, sheet 16, row 115
# processing workbook 2, sheet 16, row 117
# processing workbook 2, sheet 16, row 118
# processing workbook 2, sheet 16, row 119
# processing workbook 2, sheet 16, row 122
# processing workbook 2, sheet 16, row 123
# processing workbook 2, sheet 16, row 124
# processing workbook 2, sheet 16, row 133
# processing workbook 2, sheet 16, row 38
# processing workbook 2, sheet 16, row 40
# processing workbook 2, sheet 16, row 42
# processing workbook 2, sheet 16, row 43
# processing workbook 2, sheet 16, row 44
# processing workbook 2, sheet 16, row 45
# processing workbook 2, sheet 16, row 47
# processing workbook 2, sheet 16, row 48
# processing workbook 2, sheet 16, row 49
# processing workbook 2, sheet 16, row 51
# processing workbook 2, sheet 16, row 55
# processing workbook 2, sheet 16, row 69
# processing workbook 2, sheet 16, row 70
# processing workbook 2, sheet 16, row 71
# processing workbook 2, sheet 16, row 73
# processing workbook 2, sheet 16, row 77
# processing workbook 2, sheet 16, row 80
# processing workbook 2, sheet 16, row 81
# processing workbook 2, sheet 16, row 82
# processing workbook 2, sheet 16, row 84
# processing workbook 2, sheet 16, row 88
# processing workbook 2, sheet 16, row 95
# processing workbook 2, sheet 18, row 102
# processing workbook 2, sheet 18, row 103
# processing workbook 2, sheet 18, row 104
# processing workbook 2, sheet 18, row 106
# processing workbook 2, sheet 18, row 113
# processing workbook 2, sheet 18, row 115
# processing workbook 2, sheet 18, row 117
# processing workbook 2, sheet 18, row 118
# processing workbook 2, sheet 18, row 120
# processing workbook 2, sheet 18, row 122
# processing workbook 2, sheet 18, row 123
# processing workbook 2, sheet 18, row 124
# processing workbook 2, sheet 18, row 133
# processing workbook 2, sheet 18, row 38
# processing workbook 2, sheet 18, row 40
# processing workbook 2, sheet 18, row 41
# processing workbook 2, sheet 18, row 42
# processing workbook 2, sheet 18, row 43
# processing workbook 2, sheet 18, row 44
# processing workbook 2, sheet 18, row 45
# processing workbook 2, sheet 18, row 48
# processing workbook 2, sheet 18, row 49
# processing workbook 2, sheet 18, row 51
# processing workbook 2, sheet 18, row 62
# processing workbook 2, sheet 18, row 69
# processing workbook 2, sheet 18, row 71
# processing workbook 2, sheet 18, row 73
# processing workbook 2, sheet 18, row 80
# processing workbook 2, sheet 18, row 81
# processing workbook 2, sheet 18, row 82
# processing workbook 2, sheet 18, row 84
# processing workbook 2, sheet 18, row 91
# processing workbook 2, sheet 18, row 92
# processing workbook 2, sheet 18, row 95
# processing workbook 3, sheet 16, row 102
# processing workbook 3, sheet 16, row 103
# processing workbook 3, sheet 16, row 104
# processing workbook 3, sheet 16, row 106
# processing workbook 3, sheet 16, row 110
# processing workbook 3, sheet 16, row 113
# processing workbook 3, sheet 16, row 115
# processing workbook 3, sheet 16, row 117
# processing workbook 3, sheet 16, row 118
# processing workbook 3, sheet 16, row 119
# processing workbook 3, sheet 16, row 122
# processing workbook 3, sheet 16, row 123
# processing workbook 3, sheet 16, row 124
# processing workbook 3, sheet 16, row 133
# processing workbook 3, sheet 16, row 38
# processing workbook 3, sheet 16, row 40
# processing workbook 3, sheet 16, row 42
# processing workbook 3, sheet 16, row 43
# processing workbook 3, sheet 16, row 44
# processing workbook 3, sheet 16, row 45
# processing workbook 3, sheet 16, row 47
# processing workbook 3, sheet 16, row 48
# processing workbook 3, sheet 16, row 49
# processing workbook 3, sheet 16, row 51
# processing workbook 3, sheet 16, row 55
# processing workbook 3, sheet 16, row 69
# processing workbook 3, sheet 16, row 70
# processing workbook 3, sheet 16, row 71
# processing workbook 3, sheet 16, row 73
# processing workbook 3, sheet 16, row 77
# processing workbook 3, sheet 16, row 80
# processing workbook 3, sheet 16, row 81
# processing workbook 3, sheet 16, row 82
# processing workbook 3, sheet 16, row 84
# processing workbook 3, sheet 16, row 88
# processing workbook 3, sheet 16, row 95
# processing workbook 3, sheet 18, row 102
# processing workbook 3, sheet 18, row 103
# processing workbook 3, sheet 18, row 104
# processing workbook 3, sheet 18, row 106
# processing workbook 3, sheet 18, row 113
# processing workbook 3, sheet 18, row 115
# processing workbook 3, sheet 18, row 117
# processing workbook 3, sheet 18, row 118
# processing workbook 3, sheet 18, row 120
# processing workbook 3, sheet 18, row 122
# processing workbook 3, sheet 18, row 123
# processing workbook 3, sheet 18, row 124
# processing workbook 3, sheet 18, row 133
# processing workbook 3, sheet 18, row 38
# processing workbook 3, sheet 18, row 40
# processing workbook 3, sheet 18, row 41
# processing workbook 3, sheet 18, row 42
# processing workbook 3, sheet 18, row 43
# processing workbook 3, sheet 18, row 44
# processing workbook 3, sheet 18, row 45
# processing workbook 3, sheet 18, row 48
# processing workbook 3, sheet 18, row 49
# processing workbook 3, sheet 18, row 51
# processing workbook 3, sheet 18, row 62
# processing workbook 3, sheet 18, row 69
# processing workbook 3, sheet 18, row 71
# processing workbook 3, sheet 18, row 73
# processing workbook 3, sheet 18, row 80
# processing workbook 3, sheet 18, row 81
# processing workbook 3, sheet 18, row 82
# processing workbook 3, sheet 18, row 84
# processing workbook 3, sheet 18, row 91
# processing workbook 3, sheet 18, row 92
# processing workbook 3, sheet 18, row 95
# Done

# %%
x = merged_df

#x[(x['Year'] == 2020)&(x['Subsector'] == 'BioRef')&(x['Indicator']=='FlowOut')]['Short Description'].unique()

x[(x['Commodity']=='IFACHA')]
#x['Commodity'].unique()
# Out:
#                Process Commodity  Year                   Scenario  Indicator  \
# 5523    SATIMMarginals    IFACHA  2025  NZ10_2050A_09EESSNXCT-IMG  Marginals
# 5524    SATIMMarginals    IFACHA  2025  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 5525    SATIMMarginals    IFACHA  2026  NZ10_2050A_09EESSNXCT-IMG  Marginals
# 5526    SATIMMarginals    IFACHA  2026  NZ10_2050A_08EESSNXCT_IMG  Marginals
# 5527    SATIMMarginals    IFACHA  2026  NZ10_2099B_99NESSNXCT-IMG  Marginals
# ...                ...       ...   ...                        ...        ...
# 494304         XINDBIO    IFACHA  2054  NZ10_2050A_08EESSNXCT_IMG    FlowOut
# 494305         XINDBIO    IFACHA  2054  NZ10_2099B_99NESSNXCT-IMG    FlowOut
# 494306         XINDBIO    IFACHA  2055  NZ10_2050A_09EESSNXCT-IMG    FlowOut
# 494307         XINDBIO    IFACHA  2055  NZ10_2050A_08EESSNXCT_IMG    FlowOut
# 494308         XINDBIO    IFACHA  2055  NZ10_2099B_99NESSNXCT-IMG    FlowOut
#
#        Sector Subsector Subsubsector  \
# 5523      All       All          All
# 5524      All       All          All
# 5525      All       All          All
# 5526      All       All          All
# 5527      All       All          All
# ...       ...       ...          ...
# 494304    NaN       NaN        Other
# 494305    NaN       NaN        Other
# 494306    NaN       NaN        Other
# 494307    NaN       NaN        Other
# 494308    NaN       NaN        Other
#
#                                           TechDescription IPCC_Category_L1  \
# 5523                                SATIMMarginals Annual              NaN
# 5524                                SATIMMarginals Annual              NaN
# 5525                                SATIMMarginals Annual              NaN
# 5526                                SATIMMarginals Annual              NaN
# 5527                                SATIMMarginals Annual              NaN
# ...                                                   ...              ...
# 494304  Industry Biochar                              ...              NaN
# 494305  Industry Biochar                              ...              NaN
# 494306  Industry Biochar                              ...              NaN
# 494307  Industry Biochar                              ...              NaN
# 494308  Industry Biochar                              ...              NaN
#
#        IPCC_Category_L2 IPCC_Category_L3 IPCC_Category_L4         Description  \
# 5523                NaN              NaN              NaN  Industry - Biochar
# 5524                NaN              NaN              NaN  Industry - Biochar
# 5525                NaN              NaN              NaN  Industry - Biochar
# 5526                NaN              NaN              NaN  Industry - Biochar
# 5527                NaN              NaN              NaN  Industry - Biochar
# ...                 ...              ...              ...                 ...
# 494304              NaN              NaN              NaN  Industry - Biochar
# 494305              NaN              NaN              NaN  Industry - Biochar
# 494306              NaN              NaN              NaN  Industry - Biochar
# 494307              NaN              NaN              NaN  Industry - Biochar
# 494308              NaN              NaN              NaN  Industry - Biochar
#
#        Short Description Commodity_Name     SATIMGE
# 5523             BioChar        BioChar  146.974296
# 5524             BioChar        BioChar  162.673390
# 5525             BioChar        BioChar  174.221608
# 5526             BioChar        BioChar  168.968492
# 5527             BioChar        BioChar  100.058780
# ...                  ...            ...         ...
# 494304           BioChar        BioChar   65.645141
# 494305           BioChar        BioChar   56.679070
# 494306           BioChar        BioChar   65.535333
# 494307           BioChar        BioChar   65.323263
# 494308           BioChar        BioChar   57.019494
#
# [381 rows x 17 columns]

# %% [markdown]
# <a href="https://colab.research.google.com/github/BryceMcCall/DDPTemplateAutomationV2/blob/main/Workbooks/SATIM_Data_Inputs_W.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Onshore Wind Data Inputs

# %%
import openpyxl
import pandas as pd
import warnings

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.excel")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.drawings")

# Load data from Excel sheet
file_path = r'/content/drive/MyDrive/SATIMGE_Veda/VT_REGION1_ELC.xlsx'
sheet_name = 'ProcDataRECostProfiles'
range_cells = 'B7:L13'

# Load workbook and select the sheet
wb = openpyxl.load_workbook(file_path, data_only=True)
sheet = wb[sheet_name]

# Extract data into a DataFrame
data = sheet[range_cells]
columns = [cell.value for cell in data[0]]
df = pd.DataFrame([[cell.value for cell in row] for row in data[1:]], columns=columns)

# Remove the first row (index 0)
df = df.drop(0)

# Reset the DataFrame index
df.reset_index(drop=True, inplace=True)

# Rename the columns
new_column_names = ['Tech Name', 'TechDesc', 'Commodity In', 'Commodity Out', '*Activity I/O', '2017 Overnight Cost (2022 ZAR/kW (AC))', '2020 Overnight Cost (2022 ZAR/kW (AC))', '2025 Overnight Cost (2022 ZAR/kW (AC))', '2030 Overnight Cost (2022 ZAR/kW (AC))', '2040 Overnight Cost (2022 ZAR/kW (AC))', '2050 Overnight Cost (2022 ZAR/kW (AC))']
df.columns = new_column_names

# Remove the column at index 5 ("*Activity I/O")
df = df.drop('*Activity I/O', axis=1)

# Display the extracted data as a table
df
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#      Tech Name                               TechDesc Commodity In  \
# 0  ERSOLTC09-N  Solar Central Receiver 09 hrs storage       PWRSOL
# 1   ERSOLPCF-N                         Solar PV Fixed       PWRSOL
# 2   ERSOLPCT-N                      Solar PV tracking       PWRSOL
# 3     ERWNDH-N                                   Wind       PWRWND
# 4      ESTSUTL           Utility Scale Storage - 4hrs         ELCC
#
#   Commodity Out  2017 Overnight Cost (2022 ZAR/kW (AC))  \
# 0          ELCC                            81279.984338
# 1          ELCC                            19505.013097
# 2          ELCC                            20793.080000
# 3          ELCC                            21530.352000
# 4          ELCC                            38195.713600
#
#    2020 Overnight Cost (2022 ZAR/kW (AC))  \
# ...

# %%
import openpyxl
import pandas as pd
import warnings

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.excel")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.drawings")

# Load data from Excel sheet
file_path = r'/content/drive/MyDrive/SATIMGE_Veda/VT_REGION1_ELC.xlsx'
sheet_name = 'ProcDataRECostProfiles'
data_range_cells = 'C12:L12'  # New cell range for input data
headings_range_cells = 'C7:L7'  # New cell range for headings

# Load workbook and select the sheet
wb = openpyxl.load_workbook(file_path, data_only=True)
sheet = wb[sheet_name]

# Extract headings into a list
headings = [cell.value for cell in sheet[headings_range_cells][0]]

# Extract data into a DataFrame
data = sheet[data_range_cells]
df = pd.DataFrame([[cell.value for cell in row] for row in data], columns=headings)

# Add a new column for References (sources)
df['References'] = sheet['M12'].value  # Assuming the references are in cell M12, adjust as needed

# Rename the columns (if needed)
new_column_names = ['TechDesc', 'Commodity In', 'Commodity Out', 'Activity I/O', '2017 Overnight Cost (2022 ZAR/kW (AC))', '2020 Overnight Cost (2022 ZAR/kW (AC))', '2025 Overnight Cost (2022 ZAR/kW (AC))', '2030 Overnight Cost (2022 ZAR/kW (AC))', '2040 Overnight Cost (2022 ZAR/kW (AC))', '2050 Overnight Cost (2022 ZAR/kW (AC))', 'References']
df.columns = new_column_names

# Drop specified columns
columns_to_drop = ['Commodity In', 'Commodity Out', 'Activity I/O']
df = df.drop(columns=columns_to_drop)

# Display the modified DataFrame
df
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   TechDesc  2017 Overnight Cost (2022 ZAR/kW (AC))  \
# 0     Wind                               21530.352
#
#    2020 Overnight Cost (2022 ZAR/kW (AC))  \
# 0                                   17575
#
#    2025 Overnight Cost (2022 ZAR/kW (AC))  \
# 0                               17421.746
#
#    2030 Overnight Cost (2022 ZAR/kW (AC))  \
# 0                               17269.898
#
#    2040 Overnight Cost (2022 ZAR/kW (AC))  \
# 0                               16969.014
#
#    2050 Overnight Cost (2022 ZAR/kW (AC)) References
# 0                               16673.754       None

# %%
import openpyxl
import pandas as pd
import warnings

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.excel")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.drawings")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.worksheet._reader")

# Load data from Excel sheet
file_path = r'/content/drive/MyDrive/Doc SATIM/VT_REGION1_ELC.xlsx'
sheet_name = 'ProcDataRECostProfiles'
data_range_cells_1 = 'G12:L12'
data_range_cells_2 = 'G24:L24'

# Load workbook and select the sheet
wb = openpyxl.load_workbook(file_path, data_only=True)
sheet = wb[sheet_name]

# Extract data from the first range into a DataFrame
data_1 = sheet[data_range_cells_1]
columns_1 = ['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6']
df_1 = pd.DataFrame([[cell.value for cell in row] for row in data_1], columns=columns_1)

# Extract data from the second range into a DataFrame
data_2 = sheet[data_range_cells_2]
columns_2 = ['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6']
df_2 = pd.DataFrame([[cell.value for cell in row] for row in data_2], columns=columns_2)

# Combine the two DataFrames along the rows (axis=0)
df_combined = pd.concat([df_1, df_2], axis=0)

# Name the rows yourself
df_combined.index = ['Overnight Cost (2022 ZAR/kW)', 'LCOE (2022 R/kWh)']

# Name the columns yourself
column_names = ['2017', '2020', '2025', '2030', '2040', '2050']
df_combined.columns = column_names

# Add a new column for References (sources)
df_combined['References'] = sheet['M12'].value  # Assuming the references are in cell M12, adjust as needed

# Display the final DataFrame
df_combined
# Out:
#                                       2017          2020          2025  \
# Overnight Cost (2022 ZAR/kW)  21530.352000  17575.000000  17421.746000
# LCOE (2022 R/kWh)                 0.888591      0.725348      0.719023
#
#                                    2030       2040       2050  \
# Overnight Cost (2022 ZAR/kW)  17269.898  16969.014  16673.754
# LCOE (2022 R/kWh)                  None       None    #DIV/0!
#
#                                                                      References
# Overnight Cost (2022 ZAR/kW)  Department of Mineral Resources and Energy (20...
# LCOE (2022 R/kWh)             Department of Mineral Resources and Energy (20...

# %%
import openpyxl
import pandas as pd
import warnings

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.excel")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.drawings")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.worksheet._reader")

# Load data from Excel sheet
file_path = r'/content/drive/MyDrive/Doc SATIM/VT_REGION1_ELC.xlsx'
sheet_name = 'ProcDataRECostProfiles'
data_range_cells_1 = 'G12:L12'
data_range_cells_2 = 'G24:L24'
references_range_cells_1 = 'M12'
references_range_cells_2 = 'M24'

# Load workbook and select the sheet
wb = openpyxl.load_workbook(file_path, data_only=True)
sheet = wb[sheet_name]

# Extract data from the first range into a DataFrame
data_1 = sheet[data_range_cells_1]
columns_1 = ['2017', '2020', '2025', '2030', '2040', '2050']
df_1 = pd.DataFrame([[cell.value for cell in row] for row in data_1], columns=columns_1)

# Extract data from the second range into a DataFrame
data_2 = sheet[data_range_cells_2]
columns_2 = ['2017', '2020', '2025', '2030', '2040', '2050']
df_2 = pd.DataFrame([[cell.value for cell in row] for row in data_2], columns=columns_2)

# Combine the two DataFrames along the rows (axis=0)
df_combined = pd.concat([df_1, df_2], axis=0)

# Name the rows yourself
df_combined.index = ['Overnight Cost (2022 ZAR/kW)', 'LCOE (2022 R/kWh)']

# Extract references from the first range into a DataFrame
references_1 = sheet[references_range_cells_1].value
df_references_1 = pd.DataFrame([[references_1]], columns=['References'])

# Extract references from the second range into a DataFrame
references_2 = sheet[references_range_cells_2].value
df_references_2 = pd.DataFrame([[references_2]], columns=['References'])

# Combine the two reference DataFrames along the rows (axis=0)
df_references_combined = pd.concat([df_references_1, df_references_2], axis=0)

# Display the final DataFrames
print("Numeric Data:")
print(df_combined)
print("\nReferences:")
print(df_references_combined)
# Out:
# Numeric Data:
#                                       2017          2020          2025  \
# Overnight Cost (2022 ZAR/kW)  21530.352000  17575.000000  17421.746000
# LCOE (2022 R/kWh)                 0.888591      0.725348      0.719023
#
#                                    2030       2040       2050
# Overnight Cost (2022 ZAR/kW)  17269.898  16969.014  16673.754
# LCOE (2022 R/kWh)                  None       None    #DIV/0!
#
# References:
#                                           References
# 0  Department of Mineral Resources and Energy (20...
# 0  EPRI (2017). POWER GENERATION TECHNOLOGY DATA ...

# %%
import openpyxl
import pandas as pd
import warnings

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.excel")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.drawings")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.worksheet._reader")

# Load data from Excel sheet
file_path = r'/content/drive/MyDrive/Doc SATIM/VT_REGION1_ELC.xlsx'
sheet_name = 'ProcDataRECostProfiles'
data_range_cells_1 = 'G12:L12'
data_range_cells_2 = 'G24:L24'
reference_cell_1 = 'M12'
reference_cell_2 = 'M24'

# Load workbook and select the sheet
wb = openpyxl.load_workbook(file_path, data_only=True)
sheet = wb[sheet_name]

# Extract data from the first range into a DataFrame
data_1 = sheet[data_range_cells_1]
columns_1 = ['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6']
df_1 = pd.DataFrame([[cell.value for cell in row] for row in data_1], columns=columns_1)

# Extract data from the second range into a DataFrame
data_2 = sheet[data_range_cells_2]
columns_2 = ['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6']
df_2 = pd.DataFrame([[cell.value for cell in row] for row in data_2], columns=columns_2)

# Combine the two DataFrames along the rows (axis=0)
df_combined = pd.concat([df_1, df_2], axis=0)

# Extract references from the first range into a DataFrame
reference_1 = sheet[reference_cell_1].value
df_combined.loc[df_combined.index[0], 'References'] = reference_1

# Extract references from the second range into a DataFrame
reference_2 = sheet[reference_cell_2].value
df_combined.loc[df_combined.index[1], 'References'] = reference_2

# Specify Row Headers
df_combined.index = ['Overnight Cost (2022 ZAR/kW)', 'LCOE (2022 R/kWh)']

# Specify Column Headers
column_names = ['2017', '2020', '2025', '2030', '2040', '2050', 'References']
df_combined.columns = column_names

# Display the final DataFrame
df_combined
# Out:
#                                       2017          2020          2025  \
# Overnight Cost (2022 ZAR/kW)  21530.352000  17575.000000  17421.746000
# LCOE (2022 R/kWh)                 0.888591      0.725348      0.719023
#
#                                    2030       2040       2050  \
# Overnight Cost (2022 ZAR/kW)  17269.898  16969.014  16673.754
# LCOE (2022 R/kWh)                  None       None    #DIV/0!
#
#                                                                      References
# Overnight Cost (2022 ZAR/kW)  EPRI (2017). POWER GENERATION TECHNOLOGY DATA ...
# LCOE (2022 R/kWh)             EPRI (2017). POWER GENERATION TECHNOLOGY DATA ...

# %%
from tabulate import tabulate
import openpyxl
import pandas as pd
import warnings

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.excel")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.reader.drawings")
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.worksheet._reader")

# Load data from Excel sheet
file_path = r'/content/drive/MyDrive/Doc SATIM/VT_REGION1_ELC.xlsx'
sheet_name = 'ProcDataRECostProfiles'
data_range_cells_1 = 'G12:L12'
data_range_cells_2 = 'G24:L24'
reference_cell_1 = 'M12'
reference_cell_2 = 'M24'

# Load workbook and select the sheet
wb = openpyxl.load_workbook(file_path, data_only=True)
sheet = wb[sheet_name]

# Extract data from the first range into a DataFrame
data_1 = sheet[data_range_cells_1]
columns_1 = ['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6']
df_1 = pd.DataFrame([[cell.value for cell in row] for row in data_1], columns=columns_1)

# Extract data from the second range into a DataFrame
data_2 = sheet[data_range_cells_2]
columns_2 = ['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6']
df_2 = pd.DataFrame([[cell.value for cell in row] for row in data_2], columns=columns_2)

# Combine the two DataFrames along the rows (axis=0)
df_combined = pd.concat([df_1, df_2], axis=0)

# Extract references from the first range into a DataFrame
reference_1 = sheet[reference_cell_1].value
df_combined.loc[df_combined.index[0], 'References'] = reference_1

# Extract references from the second range into a DataFrame
reference_2 = sheet[reference_cell_2].value
df_combined.loc[df_combined.index[1], 'References'] = reference_2

# Name the rows and columns yourself
df_combined.index = ['Overnight Cost (2022 ZAR/kW)', 'LCOE (2022 R/kWh)'] # Adjust as needed

# Display the final DataFrame
table = tabulate(df_combined, headers='keys', tablefmt='github', showindex=False)
print(table)
# Out:
# |      Column1 |      Column2 |      Column3 |   Column4 |   Column5 | Column6   | References                                                                                                                                                                                                        |
# |--------------|--------------|--------------|-----------|-----------|-----------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 21530.4      | 17575        | 17421.7      |   17269.9 |     16969 | 16673.754 | EPRI (2017). POWER GENERATION TECHNOLOGY DATA FOR INTEGRATED RESOURCE PLAN OF SOUTH AFRICA. [online] Available at: https://www.energy.gov.za/IRP/irp-update-draft-report2018/EPRI-Report-2017.pdf Tables 17 - 20. |
# ...
